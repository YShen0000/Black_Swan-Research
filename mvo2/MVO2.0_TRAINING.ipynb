# %% [markdown]
# # Preparation

# %%
# !pip install quandl
# !pip install arch
# !pip install PyPortfolioOpt
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: quandl in /opt/atomsci-env/lib/python3.8/site-packages (3.7.0)
# Requirement already satisfied: more-itertools in /opt/atomsci-env/lib/python3.8/site-packages (from quandl) (10.2.0)
# Requirement already satisfied: requests>=2.7.0 in /opt/atomsci-env/lib/python3.8/site-packages (from quandl) (2.31.0)
# Requirement already satisfied: python-dateutil in /opt/atomsci-env/lib/python3.8/site-packages (from quandl) (2.8.2)
# Requirement already satisfied: six in /opt/atomsci-env/lib/python3.8/site-packages (from quandl) (1.16.0)
# Requirement already satisfied: numpy>=1.8 in /opt/atomsci-env/lib/python3.8/site-packages (from quandl) (1.23.5)
# Requirement already satisfied: pandas>=0.14 in /opt/atomsci-env/lib/python3.8/site-packages (from quandl) (2.0.3)
# Requirement already satisfied: inflection>=0.3.1 in /opt/atomsci-env/lib/python3.8/site-packages (from quandl) (0.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/atomsci-env/lib/python3.8/site-packages (from requests>=2.7.0->quandl) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/atomsci-env/lib/python3.8/site-packages (from requests>=2.7.0->quandl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/atomsci-env/lib/python3.8/site-packages (from requests>=2.7.0->quandl) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/atomsci-env/lib/python3.8/site-packages (from requests>=2.7.0->quandl) (3.3.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.14->quandl) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.14->quandl) (2024.1)
# Requirement already satisfied: arch in /opt/atomsci-env/lib/python3.8/site-packages (5.6.0)
# Requirement already satisfied: numpy>=1.17 in /opt/atomsci-env/lib/python3.8/site-packages (from arch) (1.23.5)
# Requirement already satisfied: scipy>=1.3 in /opt/atomsci-env/lib/python3.8/site-packages (from arch) (1.8.1)
# Requirement already satisfied: statsmodels>=0.11 in /opt/atomsci-env/lib/python3.8/site-packages (from arch) (0.14.1)
# Requirement already satisfied: pandas>=1.0 in /opt/atomsci-env/lib/python3.8/site-packages (from arch) (2.0.3)
# Requirement already satisfied: property-cached>=1.6.4 in /opt/atomsci-env/lib/python3.8/site-packages (from arch) (1.6.4)
# Requirement already satisfied: packaging>=21.3 in /opt/atomsci-env/lib/python3.8/site-packages (from statsmodels>=0.11->arch) (23.2)
# Requirement already satisfied: patsy>=0.5.4 in /opt/atomsci-env/lib/python3.8/site-packages (from statsmodels>=0.11->arch) (0.5.6)
# Requirement already satisfied: tzdata>=2022.1 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=1.0->arch) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=1.0->arch) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=1.0->arch) (2.8.2)
# Requirement already satisfied: six in /opt/atomsci-env/lib/python3.8/site-packages (from patsy>=0.5.4->statsmodels>=0.11->arch) (1.16.0)
# Requirement already satisfied: PyPortfolioOpt in /opt/atomsci-env/lib/python3.8/site-packages (1.5.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /opt/atomsci-env/lib/python3.8/site-packages (from PyPortfolioOpt) (1.5.1)
# Requirement already satisfied: scipy<2.0,>=1.3 in /opt/atomsci-env/lib/python3.8/site-packages (from PyPortfolioOpt) (1.8.1)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /opt/atomsci-env/lib/python3.8/site-packages (from PyPortfolioOpt) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in /opt/atomsci-env/lib/python3.8/site-packages (from PyPortfolioOpt) (2.0.3)
# Requirement already satisfied: osqp>=0.6.2 in /opt/atomsci-env/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.6.7)
# Requirement already satisfied: clarabel>=0.5.0 in /opt/atomsci-env/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.8.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /opt/atomsci-env/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (3.2.4.post2)
# Requirement already satisfied: ecos>=2 in /opt/atomsci-env/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (2.0.13)
# Requirement already satisfied: tzdata>=2022.1 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.19->PyPortfolioOpt) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.19->PyPortfolioOpt) (2024.1)
# Requirement already satisfied: qdldl in /opt/atomsci-env/lib/python3.8/site-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.1.7.post2)
# Requirement already satisfied: six>=1.5 in /opt/atomsci-env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Requirement already satisfied: pandas-datareader in /opt/atomsci-env/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: lxml in /opt/atomsci-env/lib/python3.8/site-packages (from pandas-datareader) (5.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: pandas>=0.23 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas-datareader) (2.0.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/atomsci-env/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/atomsci-env/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/atomsci-env/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/atomsci-env/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3; python_version < "3.10" in /opt/atomsci-env/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (1.23.5)
# Requirement already satisfied: six>=1.5 in /opt/atomsci-env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dt
import datetime
import quandl
import math
from statsmodels.stats.diagnostic import het_arch
from arch import arch_model
from pypfopt import EfficientFrontier,objective_functions
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn import metrics
from copy import deepcopy

# %%
import sklearn
sklearn.__version__
# Out:
# '1.3.2'

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
def modify_date(date):
    return date[:10]

# %%
def data_cleaning(data):
    if (data.isna()).any().any():
        missing = np.where(data.isna())
        rows=missing[0]
        cols=missing[1]
        print(rows)
        for row in range(len(rows)):
            col=cols[row]
            if row == len(data)-1:
                data.iloc[row,col]=data.iloc[row-1,col]**2/data.iloc[row-2,col]
            elif row ==0:
                data.iloc[row,col]=data.iloc[row+1,col]**2/data.iloc[row+2,col]
            else:
                data.iloc[row,col]=math.sqrt(data.iloc[row-1,col]*data.iloc[row+1,col])
        print(data)

# %%
def get_price_years_ago(data, date,time):
    year_ago=date-datetime.timedelta(days=int(time*365))
    price_year_ago=data[data.index<=year_ago]
    return price_year_ago

# %%
def max_drawdown_absolute(returns):
    r = returns.add(1).cumprod()
    dd = r.div(r.cummax()).sub(1)
    mdd = dd.min()
    end = dd.argmin()
    start = r.iloc[:end].argmax()
    return abs(mdd), start, end

# %%
def fit_garch(data,p,q):
    lag = max(p,q)
    length =res.shape[0]
    am = arch_model(res, vol='Garch', p=1, o=0, q=1, dist='Normal')
    split_date = one_year_monthly_return.index.values[lag-1]
    results = am.fit(last_obs=split_date)
    forecasts = results.forecast(horizon=1, start = length-lag, method='simulation', simulations=1000)
    sims = forecasts.variance
    std = np.sqrt(np.sum(sims)*12/lag)
    return std

# %%
def post_allocation(dfMVOweight):

    dfMVOweight['equal']=1/len(dfMVOweight)
    numofstocks=len(dfMVOweight)
    allocationweight=allocation.loc[numofstocks,:]
    dfMVOweight['proportion']=''
    dfMVOweight['adjusted proportion']=''
    dfMVOweight['direct']=''
    residual=0
    for i in range(numofstocks):
        dfMVOweight.iloc[i,4]=dfMVOweight.iloc[i,1]/np.sum(dfMVOweight['PR_SR'])
        if (dfMVOweight.iloc[i,4]+residual/(numofstocks-i))>allocationweight[0]:
            dfMVOweight.iloc[i,5]=allocationweight[0]
        else:
            dfMVOweight.iloc[i,5]=(dfMVOweight.iloc[i,4]+residual/(numofstocks-i))
        residual+=dfMVOweight.iloc[i,4]-dfMVOweight.iloc[i,5]
    for i in range(int(allocationweight[1])):
        dfMVOweight.iloc[i,6]=allocationweight[0]
    for i in range(int(allocationweight[1]),int(allocationweight[1]+allocationweight[3])):
        dfMVOweight.iloc[i,6]=allocationweight[2]
    return dfMVOweight

# %%
def output(weight):
    if stock_type == "S&P100":
        OEX=pdr.get_data_yahoo("^OEX", start=start_swan_date, end=end_swan_date)["Adj Close"]

    elif stock_type == "S&P500":
        OEX=pdr.get_data_yahoo("SPY", start=start_swan_date, end=end_swan_date)["Adj Close"]

    stock_price=pdr.get_data_yahoo(list(weight.index), start=start_swan_date, end=end_swan_date)["Adj Close"]
    OEX.to_csv("oex.csv")
    injected_result = pd.DataFrame(index = stock_price.index )
    S1=np.array(10000*weight.T)/np.array(stock_price.iloc[0,:]).T
    portfolio_value = stock_price@S1.T
    injected_result["portfolio_value"]=portfolio_value
    S2 = 10000/float(OEX[0])
    injected_result["oex"]=S2*OEX
    return injected_result

# %% [markdown]
# # Step 1 - Preselection

# %%
# Preselection parameters set up
method = "db"          # or avg or anyother method
stock_type = "S&P100"
end_swan = "Swan10a"         #equals the last swan before the swan we are going to predict
start_swan="Swan4"
start = dt(2019,1,1)
end = dt(2022,1,1)
selected_stock_number = 22     #number of stock preselected
start_swan_date = dt(2022,1,3)
end_swan_date = dt(2023,1,3)
w1 = 0.17
w2 = 0.17
MA_days = 30
N = 7 # This parameter is set to help classification method like K-means

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/atomsci-env/lib/python3.8/site-packages (3.1.3)
# Requirement already satisfied: et-xmlfile in /opt/atomsci-env/lib/python3.8/site-packages (from openpyxl) (1.1.0)

# %%
#read all stocks and their swan beta
if stock_type == "S&P100":
    portfolio_beta = pd.read_excel("All_SwanBeta100.xlsx",index_col=0)
else:
    portfolio_beta = pd.read_excel("All_SwanBeta500.xlsx",index_col=0)

# %%
selected_swans_var=portfolio_beta.loc[:,start_swan:end_swan]
portfolio_beta =portfolio_beta[ selected_swans_var.T.isnull().sum()<selected_swans_var.shape[1]-1]

# %%
portfolio_beta
# Out:
#           Swan-3    Swan-2    Swan-1     Swan1     Swan2     Swan3     Swan4  \
# Ticker
# CHTR         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# GM           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# KMI          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# GOOG         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# GOOGL        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...          ...       ...       ...       ...       ...       ...       ...
# UNP     0.850695  2.127809  1.993802  1.088334  0.427848  0.418409  0.283910
# USB     0.407208  0.375769  0.483245  0.176170  1.187362  1.307068  0.811824
# WFC     1.388900  1.261192  1.686449  0.558622  1.587780  1.233240  0.300985
# WMT     0.897873 -1.424131  0.462878  1.059818  1.484265  0.762944  0.586029
# XOM     1.007288  0.845021 -0.532604  0.914433  0.008834  0.475580  0.716433
#
#            Swan5     Swan6     Swan7     Swan8     Swan9   Swan10a   Swan10b
# Ticker
# CHTR         NaN  1.583170  0.649030  0.797374  0.939407  1.060138  1.278190
# GM           NaN  2.026711  0.792127  0.190040  1.553517  2.447747  1.934870
# KMI          NaN  0.540529  1.230239  0.919927  1.592887 -1.141071 -0.541752
# GOOG    0.803565  1.167641  0.916183  0.944312  0.976498  0.875866  1.104899
# GOOGL   0.803565  1.167641  0.870361  0.938163  0.979057  0.880849  1.117074
# ...          ...       ...       ...       ...       ...       ...       ...
# UNP     1.275539  1.334344  1.354688  1.049957  1.188887 -0.200038  0.632258
# USB     1.672467  0.905422  0.995170  0.906766  1.495656  0.501194  0.825853
# WFC     1.698834  1.182443  0.995686  0.827634  1.470901  0.571633  1.078228
# WMT     0.461023  0.235666  0.982186  0.414455  0.078002  0.291725  0.710631
# XOM     0.396490  0.938817  1.138592  1.161731  1.518454 -2.833257 -2.305610
#
# [95 rows x 14 columns]

# %%
corr=portfolio_beta.corr()
selected_corr=corr.loc["Swan1":end_swan,"Swan1":end_swan]
corr1={}
for i in range(selected_corr.shape[1]):
    for j in range(i+1,selected_corr.shape[0]):
        selected_corr.iloc[j,i]=np.nan

# %%
selected_corr
# Out:
#          Swan1     Swan2     Swan3     Swan4     Swan5     Swan6     Swan7  \
# Swan1      1.0 -0.004268  0.111982  0.050073  0.001444  0.101963  0.079685
# Swan2      NaN  1.000000  0.549511  0.335485  0.410861  0.392490  0.033937
# Swan3      NaN       NaN  1.000000  0.151778  0.258652  0.435457  0.243705
# Swan4      NaN       NaN       NaN  1.000000 -0.032138  0.143125  0.147027
# Swan5      NaN       NaN       NaN       NaN  1.000000  0.444474  0.221512
# Swan6      NaN       NaN       NaN       NaN       NaN  1.000000  0.301317
# Swan7      NaN       NaN       NaN       NaN       NaN       NaN  1.000000
# Swan8      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Swan9      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Swan10a    NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             Swan8     Swan9   Swan10a
# Swan1    0.076826  0.037902 -0.051585
# Swan2    0.307858  0.035989  0.412956
# Swan3    0.224528  0.103467  0.297051
# Swan4    0.225411  0.088824  0.271980
# Swan5    0.208068  0.564402 -0.048352
# Swan6    0.482711  0.404329  0.087378
# Swan7    0.185835  0.164183 -0.119691
# Swan8    1.000000  0.236622 -0.093087
# Swan9         NaN  1.000000 -0.351039
# Swan10a       NaN       NaN  1.000000

# %%
avg=selected_corr.mean(axis=1)
weight_swan = avg/sum(avg)
selected_beata=portfolio_beta.loc[:,start_swan:end_swan].fillna(0)
#portfolio_beta["corr_beta"]=selected_beata@weight_swan
#portfolio_beta=portfolio_beta.sort_values(by=["corr_beta"])

# %%
portfolio_beta
# Out:
#           Swan-3    Swan-2    Swan-1     Swan1     Swan2     Swan3     Swan4  \
# Ticker
# CHTR         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# GM           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# KMI          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# GOOG         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# GOOGL        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...          ...       ...       ...       ...       ...       ...       ...
# UNP     0.850695  2.127809  1.993802  1.088334  0.427848  0.418409  0.283910
# USB     0.407208  0.375769  0.483245  0.176170  1.187362  1.307068  0.811824
# WFC     1.388900  1.261192  1.686449  0.558622  1.587780  1.233240  0.300985
# WMT     0.897873 -1.424131  0.462878  1.059818  1.484265  0.762944  0.586029
# XOM     1.007288  0.845021 -0.532604  0.914433  0.008834  0.475580  0.716433
#
#            Swan5     Swan6     Swan7     Swan8     Swan9   Swan10a   Swan10b
# Ticker
# CHTR         NaN  1.583170  0.649030  0.797374  0.939407  1.060138  1.278190
# GM           NaN  2.026711  0.792127  0.190040  1.553517  2.447747  1.934870
# KMI          NaN  0.540529  1.230239  0.919927  1.592887 -1.141071 -0.541752
# GOOG    0.803565  1.167641  0.916183  0.944312  0.976498  0.875866  1.104899
# GOOGL   0.803565  1.167641  0.870361  0.938163  0.979057  0.880849  1.117074
# ...          ...       ...       ...       ...       ...       ...       ...
# UNP     1.275539  1.334344  1.354688  1.049957  1.188887 -0.200038  0.632258
# USB     1.672467  0.905422  0.995170  0.906766  1.495656  0.501194  0.825853
# WFC     1.698834  1.182443  0.995686  0.827634  1.470901  0.571633  1.078228
# WMT     0.461023  0.235666  0.982186  0.414455  0.078002  0.291725  0.710631
# XOM     0.396490  0.938817  1.138592  1.161731  1.518454 -2.833257 -2.305610
#
# [95 rows x 14 columns]

# %%
if method == "gamma":
    portfolio_beta["avg"]=portfolio_beta.loc[:,start_swan:end_swan].mean(axis=1)
    portfolio_beta["avg_sd"]=portfolio_beta.loc[:,start_swan:end_swan].mean(axis=1)+portfolio_beta.loc[:,start_swan:end_swan].std(axis=1,ddof=0)
    portfolio_beta=portfolio_beta.sort_values(by=["avg_sd"])
    preselected_stock = portfolio_beta.iloc[:selected_stock_number,:]
elif method =="average":
    portfolio_beta["avg"]=portfolio_beta.loc[:,start_swan:end_swan].mean(axis=1)
    #Select 18 stocks
    portfolio_beta=portfolio_beta.sort_values(by=["avg"])
    preselected_stock = portfolio_beta.iloc[:selected_stock_number,:]

elif method == "K_means":
    selected_beta =portfolio_beta.loc[:,start_swan:end_swan].dropna()
    Y_predic = selected_beta[end_swan].copy()
    Kmean = KMeans(n_clusters=N,random_state=1,n_init=10)#set the random_state to keep modeling the same every run
    Kmean.fit(selected_beta)
    ct = Kmean.cluster_centers_
    labels = Kmean.labels_
    current_dbscore=metrics.davies_bouldin_score(selected_beta, labels)
    print(current_dbscore)
    selected_beta["Group"]=Kmean.labels_
    print(selected_beta['Group'])
    res = ct.mean(axis=1)
    res [res<0]=0

    min_group = np.where(res==min(res))
    for i in range(N):
        Y_predic[selected_beta["Group"] == i] = res [i]
    selected_beta ["avg"]=Y_predic.values
    selected_beta=selected_beta.sort_values(by=["avg"])
    first_group=selected_beta[selected_beta["Group"]==selected_beta["Group"][0]]
    if first_group.shape[0] <10:
        second_group = selected_beta[selected_beta["Group"]==selected_beta["Group"][first_group.shape[0]]]
        preselected_stock = pd.concat([first_group,second_group],axis=0,ignore_index=True)
    else:
        preselected_stock = first_group
        
elif method == "gpt":
    tickers = ['AMZN', 'AAPL', 'MSFT', 'GOOGL', 'NVDA', 'NFLX', 'MA', 'V', 'UNH', 'JPM', 'GS', 'COST', 'HD', 'TGT', 'ADBE', 'BAC', 'LMT', 'BRK-B']
    preselected_stock = portfolio_beta.loc[tickers, start_swan:end_swan]
    preselected_stock["avg"] = preselected_stock.loc[:, start_swan:end_swan].mean(axis=1)
    print("Selected Stocks (GPT):")
    for _, row in preselected_stock.iterrows():
        print(f"Ticker: {row.name}, Average: {row['avg']}")
    print("=" * 50)
    
elif method == "gptLowest8":
    tickers =  ['AMZN', 'AAPL', 'MSFT', 'GOOGL', 'NVDA', 'NFLX', 'MA', 'V', 'UNH', 'JPM', 'GS', 'COST', 'HD', 'TGT', 'ADBE', 'BAC', 'LMT', 'BRK-B']
    preselected_stock = portfolio_beta.loc[tickers, start_swan:end_swan]
    preselected_stock["avg"] = preselected_stock.loc[:, start_swan:end_swan].mean(axis=1)
    print("Selected Stocks (GPT):")
    for _, row in preselected_stock.iterrows():
        print(f"Ticker: {row.name}, Average: {row['avg']}")
    print("=" * 50)

elif method == "db":
    selected_beta =portfolio_beta.loc[:,start_swan:end_swan].dropna()
    Y_predic = selected_beta[end_swan].copy()
    dbscore_tracker = []
    for R in range(1, 1001):  # Loop through random seeds
        Kmean = KMeans(n_clusters=N,random_state=1,n_init=10)#set the random_state to keep modeling the same every run
        Kmean.fit(selected_beta)
        ct = Kmean.cluster_centers_
        labels = Kmean.labels_
        current_dbscore=metrics.davies_bouldin_score(selected_beta, labels)
        print(current_dbscore)
        selected_beta["Group"]=Kmean.labels_
        print(selected_beta['Group'])
        res = ct.mean(axis=1)
        res [res<0]=0
        
        min_group = np.where(res==min(res))
        for i in range(N):
            Y_predic[selected_beta["Group"] == i] = res [i]
            selected_beta ["avg"]=Y_predic.values
            selected_beta=selected_beta.sort_values(by=["avg"])
            first_group=selected_beta[selected_beta["Group"]==selected_beta["Group"][0]]
        if first_group.shape[0] <10:
            second_group = selected_beta[selected_beta["Group"]==selected_beta["Group"][first_group.shape[0]]]
            preselected_stock = pd.concat([first_group,second_group],axis=0,ignore_index=True)
        else:
            preselected_stock = first_group
# Out:
# 1.2893048756456593
# Ticker
# ACN     3
# BKNG    3
# BLK     6
# GS      6
# MDLZ    1
#        ..
# UNP     2
# USB     2
# WFC     2
# WMT     1
# XOM     4
# Name: Group, Length: 86, dtype: int32
# 0.976056259506848
# Ticker
# COP     4
# C       0
# SLB     4
# TMO     2
# XOM     4
#        ..
# MCD     5
# VZ      6
# GD      1
# LLY     6
# MSFT    2
# Name: Group, Length: 86, dtype: int32
# 1.0948590116418058
# Ticker
# SO      0
# DHR     2
# CVS     0
# COF     1
# AAPL    2
#        ..
# TXN     2
# WMT     0
# EMR     4
# COP     5
# JNJ     0
# Name: Group, Length: 86, dtype: int32
# 0.8933846414587983
# Ticker
# CMCSA    1
# ABT      1
# KO       2
# UNH      2
# LOW      1
#         ..
# BLK      4
# WBA      1
# LLY      2
# MO       2
# GE       0
# Name: Group, Length: 86, dtype: int32
# 1.0032155417425013
# Ticker
# TGT     0
# IBM     0
# INTC    0
# PFE     0
# SPG     6
#        ..
# AIG     5
# EMR     5
# T       0
# BLK     4
# ACN     1
# Name: Group, Length: 86, dtype: int32
# 0.9806973640757002
# Ticker
# VZ      2
# BLK     0
# MO      2
# NVDA    6
# HD      6
#        ..
# CL      2
# C       0
# MDT     2
# MET     4
# WBA     1
# Name: Group, Length: 86, dtype: int32
# 1.011942361407659
# Ticker
# BLK     5
# MDLZ    3
# COF     5
# MO      3
# ADBE    5
#        ..
# WFC     2
# GILD    1
# LLY     3
# FDX     5
# EXC     3
# Name: Group, Length: 86, dtype: int32
# 0.9623976801812351
# Ticker
# MS      3
# DUK     1
# BIIB    5
# SO      1
# SBUX    2
#        ..
# AMZN    5
# TXN     5
# MRK     1
# RTX     4
# AAPL    5
# Name: Group, Length: 86, dtype: int32
# 1.2417885733707748
# Ticker
# BRK-B    6
# C        4
# GD       2
# XOM      5
# HD       0
#         ..
# TMO      3
# NVDA     0
# LOW      3
# SO       1
# KO       1
# Name: Group, Length: 86, dtype: int32
# 0.9207069628729213
# Ticker
# ACN     5
# AMZN    2
# CVX     4
# GD      0
# SBUX    3
#        ..
# LOW     2
# UPS     3
# PEP     3
# EMR     0
# HD      5
# Name: Group, Length: 86, dtype: int32
# 1.0078685518561412
# Ticker
# WBA      2
# KO       4
# AAPL     2
# MMM      2
# TMO      2
#         ..
# MDLZ     4
# FDX      1
# UPS      4
# PEP      4
# BRK-B    5
# Name: Group, Length: 86, dtype: int32
# 1.0857341470484523
# Ticker
# BIIB    2
# MO      6
# NKE     2
# INTC    2
# LOW     2
#        ..
# HD      5
# BA      1
# MS      1
# LLY     6
# JPM     1
# Name: Group, Length: 86, dtype: int32
# 0.8522139588113643
# Ticker
# PEP     2
# LOW     4
# USB     5
# DIS     0
# MDLZ    2
#        ..
# T       4
# COST    1
# LLY     1
# VZ      1
# XOM     3
# Name: Group, Length: 86, dtype: int32
# 0.969953648718479
# Ticker
# CMCSA    1
# XOM      0
# MS       3
# EMR      4
# PFE      1
#         ..
# QCOM     1
# AMT      6
# LLY      2
# COST     2
# AMGN     2
# Name: Group, Length: 86, dtype: int32
# 0.9807322199840848
# Ticker
# OXY      3
# GILD     2
# BRK-B    5
# HON      0
# BMY      5
#         ..
# MMM      2
# NVDA     6
# BLK      0
# F        0
# AMT      6
# Name: Group, Length: 86, dtype: int32
# 1.0537148771533278
# Ticker
# SPG     5
# MS      0
# KO      5
# ORCL    3
# UNP     2
#        ..
# QCOM    3
# BMY     1
# COP     4
# UPS     5
# MRK     1
# Name: Group, Length: 86, dtype: int32
# 0.8444123864764869
# Ticker
# MRK     1
# F       4
# OXY     5
# TXN     2
# CVS     1
#        ..
# HD      3
# EMR     6
# BIIB    2
# COP     5
# SPG     0
# Name: Group, Length: 86, dtype: int32
# 1.054053804718686
# Ticker
# AMGN    0
# MS      4
# AXP     3
# TMO     6
# AMT     1
#        ..
# BAC     4
# CVX     2
# IBM     6
# SPG     5
# LLY     0
# Name: Group, Length: 86, dtype: int32
# 1.0518033187796298
# Ticker
# UNP     2
# MRK     0
# GILD    4
# PFE     4
# ADBE    6
#        ..
# SPG     1
# F       6
# BK      6
# ACN     5
# AIG     2
# Name: Group, Length: 86, dtype: int32
# 1.0954282240348316
# Ticker
# CAT     2
# HON     0
# LMT     4
# GE      2
# GILD    3
#        ..
# BK      0
# UNH     5
# BAC     0
# AAPL    3
# MRK     1
# Name: Group, Length: 86, dtype: int32
# 0.8771527908863023
# Ticker
# OXY     5
# RTX     6
# TGT     0
# ORCL    0
# MSFT    0
#        ..
# QCOM    0
# LOW     0
# SPG     3
# CSCO    0
# BA      1
# Name: Group, Length: 86, dtype: int32
# 0.9894762359279105
# Ticker
# CSCO    1
# GE      0
# EXC     4
# PG      2
# WFC     0
#        ..
# ADBE    3
# HD      6
# EMR     0
# ABT     1
# BKNG    6
# Name: Group, Length: 86, dtype: int32
# 0.9277831735707645
# Ticker
# FDX      1
# DHR      2
# LLY      4
# ALL      5
# IBM      2
#         ..
# BRK-B    4
# GILD     2
# LOW      2
# T        2
# CL       6
# Name: Group, Length: 86, dtype: int32
# 0.9391817396780489
# Ticker
# PG      1
# AAPL    3
# RTX     4
# SPG     1
# AMT     5
#        ..
# BMY     6
# MDLZ    1
# LOW     3
# NVDA    5
# GILD    3
# Name: Group, Length: 86, dtype: int32
# 0.8388753337894348
# Ticker
# USB     1
# SO      5
# MCD     5
# DHR     3
# ORCL    3
#        ..
# OXY     2
# BKNG    6
# BK      0
# LMT     2
# RTX     1
# Name: Group, Length: 86, dtype: int32
# 1.066209516289927
# Ticker
# AMGN    6
# USB     1
# TMO     3
# LMT     4
# GILD    3
#        ..
# BMY     6
# FDX     5
# CL      0
# DIS     5
# PFE     3
# Name: Group, Length: 86, dtype: int32
# 0.8807571350686717
# Ticker
# PFE     1
# AAPL    1
# SBUX    5
# F       4
# FDX     4
#        ..
# ABT     1
# INTC    1
# DHR     1
# NEE     5
# AMGN    2
# Name: Group, Length: 86, dtype: int32
# 0.9218110305511443
# Ticker
# AMGN    3
# MMM     5
# MDLZ    6
# C       4
# ABT     5
#        ..
# UNP     1
# AMT     0
# MO      3
# COP     2
# FDX     4
# Name: Group, Length: 86, dtype: int32
# 0.9679841723378683
# Ticker
# BA      6
# SBUX    1
# AIG     2
# CVS     3
# ABT     5
#        ..
# USB     2
# TXN     5
# MMM     5
# C       6
# IBM     5
# Name: Group, Length: 86, dtype: int32
# 0.9789762026634821
# Ticker
# BMY     0
# GE      5
# GILD    4
# MS      6
# ADBE    6
#        ..
# CAT     5
# QCOM    4
# MET     5
# CVS     0
# JNJ     0
# Name: Group, Length: 86, dtype: int32
# 0.9705084037381569
# Ticker
# MS      3
# WMT     5
# BMY     5
# F       3
# PEP     1
#        ..
# NVDA    6
# MO      5
# COST    5
# QCOM    0
# HD      6
# Name: Group, Length: 86, dtype: int32
# 1.0624630751262367
# Ticker
# MO      5
# GE      1
# PG      6
# TXN     0
# CSCO    0
#        ..
# UPS     6
# COF     4
# PEP     6
# CVX     2
# SBUX    6
# Name: Group, Length: 86, dtype: int32
# 1.0516633926466001
# Ticker
# RTX     0
# ADBE    2
# ORCL    3
# BIIB    3
# TXN     3
#        ..
# LOW     3
# BK      2
# TMO     3
# DUK     5
# FDX     2
# Name: Group, Length: 86, dtype: int32
# 0.900825596967434
# Ticker
# GS      1
# MMM     3
# PEP     6
# EXC     5
# DD      1
#        ..
# WFC     2
# LMT     4
# FDX     1
# SBUX    6
# ABT     3
# Name: Group, Length: 86, dtype: int32
# 1.068489541095461
# Ticker
# LOW     3
# COF     0
# NVDA    6
# MDLZ    1
# BAC     0
#        ..
# MSFT    3
# UNH     1
# MDT     1
# PEP     1
# DIS     0
# Name: Group, Length: 86, dtype: int32
# 0.8609037545311251
# Ticker
# WFC     0
# EXC     1
# BLK     3
# AMGN    1
# INTC    6
#        ..
# BAC     3
# BKNG    4
# CL      5
# MRK     1
# NVDA    4
# Name: Group, Length: 86, dtype: int32
# 0.9739609823838469
# Ticker
# RTX     1
# NEE     2
# HD      0
# CVX     5
# HON     3
#        ..
# WFC     1
# AMZN    2
# NKE     4
# BK      3
# XOM     5
# Name: Group, Length: 86, dtype: int32
# 0.9057520579279561
# Ticker
# BIIB    5
# AAPL    5
# DHR     5
# ALL     4
# SPG     2
#        ..
# BK      0
# CL      2
# AXP     4
# NEE     2
# GE      4
# Name: Group, Length: 86, dtype: int32
# 1.0225794019458936
# Ticker
# GE     5
# PEP    1
# WMT    6
# MS     4
# MCD    1
#       ..
# AIG    5
# CVX    2
# TGT    0
# FDX    4
# TXN    0
# Name: Group, Length: 86, dtype: int32
# 1.0397850381569271
# Ticker
# EXC      1
# UPS      0
# TMO      3
# GS       4
# GILD     3
#         ..
# COP      5
# MS       4
# PEP      0
# CVS      1
# BRK-B    1
# Name: Group, Length: 86, dtype: int32
# 1.0471769764541983
# Ticker
# IBM     1
# BMY     6
# ORCL    1
# OXY     2
# PEP     0
#        ..
# AIG     5
# F       4
# COF     4
# MMM     1
# NVDA    3
# Name: Group, Length: 86, dtype: int32
# 1.0621877488858593
# Ticker
# VZ      4
# AAPL    2
# BAC     5
# WBA     2
# BIIB    2
#        ..
# SO      1
# F       5
# AIG     6
# TMO     2
# JNJ     4
# Name: Group, Length: 86, dtype: int32
# 1.0358373202524895
# Ticker
# MET      1
# AMGN     5
# QCOM     4
# DUK      5
# XOM      3
#         ..
# NVDA     0
# IBM      4
# CMCSA    4
# JNJ      5
# WMT      5
# Name: Group, Length: 86, dtype: int32
# 1.0861277937056568
# Ticker
# RTX      2
# BKNG     5
# TGT      4
# ALL      2
# NEE      6
#         ..
# AMZN     6
# BIIB     4
# CMCSA    4
# TMO      4
# SBUX     6
# Name: Group, Length: 86, dtype: int32
# 0.9082706942602435
# Ticker
# LOW    2
# UNP    0
# MS     3
# MET    0
# TXN    2
#       ..
# LLY    5
# RTX    0
# MDT    4
# AMT    1
# BLK    3
# Name: Group, Length: 86, dtype: int32
# 1.0499925061109168
# Ticker
# ADBE    3
# IBM     0
# KO      1
# GE      4
# CVS     5
#        ..
# COST    5
# LOW     0
# ACN     6
# FDX     3
# UNH     1
# Name: Group, Length: 86, dtype: int32
# 0.9903688094398501
# Ticker
# F       1
# ABT     0
# EMR     4
# SO      6
# JNJ     2
#        ..
# QCOM    0
# UNP     4
# TXN     0
# MS      1
# GS      1
# Name: Group, Length: 86, dtype: int32
# 0.8957665128564186
# Ticker
# HON      0
# T        3
# SLB      5
# BRK-B    2
# CSCO     3
#         ..
# QCOM     3
# NEE      4
# F        0
# ALL      1
# MDLZ     4
# Name: Group, Length: 86, dtype: int32
# 1.0196476449567875
# Ticker
# PG      1
# AIG     0
# SO      1
# GE      0
# TXN     4
#        ..
# CVS     3
# PEP     1
# AAPL    4
# INTC    4
# CL      1
# Name: Group, Length: 86, dtype: int32
# 0.9542721033168691
# Ticker
# WMT     0
# UPS     6
# BKNG    5
# NKE     2
# MDLZ    6
#        ..
# TXN     2
# CL      6
# EMR     3
# OXY     4
# ADBE    1
# Name: Group, Length: 86, dtype: int32
# 0.9573418764882609
# Ticker
# HD       5
# BMY      4
# CVS      4
# PFE      6
# CMCSA    6
#         ..
# BIIB     6
# AIG      3
# JPM      1
# T        6
# ORCL     6
# Name: Group, Length: 86, dtype: int32
# 0.9372796063213816
# Ticker
# EXC     2
# USB     5
# BKNG    4
# LMT     6
# CVX     6
#        ..
# GD      5
# F       3
# MDLZ    1
# AXP     5
# HD      4
# Name: Group, Length: 86, dtype: int32
# 1.0601512376975573
# Ticker
# INTC    2
# LOW     2
# SLB     4
# MCD     0
# EXC     5
#        ..
# SBUX    0
# WMT     5
# T       2
# BA      6
# TGT     2
# Name: Group, Length: 86, dtype: int32
# 0.9284366654949877
# Ticker
# ABT     0
# PG      3
# BAC     1
# RTX     4
# USB     4
#        ..
# WMT     2
# VZ      2
# QCOM    0
# UNH     3
# TGT     0
# Name: Group, Length: 86, dtype: int32
# 1.0343149415723853
# Ticker
# WFC     1
# ALL     1
# INTC    3
# MET     1
# GS      0
#        ..
# AAPL    3
# UNH     5
# SBUX    5
# MDLZ    5
# QCOM    3
# Name: Group, Length: 86, dtype: int32
# 1.077379382083338
# Ticker
# HD       3
# CL       6
# QCOM     1
# DUK      0
# MMM      1
#         ..
# SPG      6
# ABT      1
# CMCSA    1
# HON      5
# BK       5
# Name: Group, Length: 86, dtype: int32
# 0.8833926379790898
# Ticker
# BK      4
# BIIB    1
# GILD    1
# WFC     5
# USB     5
#        ..
# COP     3
# T       1
# ADBE    4
# BKNG    0
# LOW     1
# Name: Group, Length: 86, dtype: int32
# 1.0946449418741078
# Ticker
# SO      0
# C       6
# MET     1
# UNP     1
# SBUX    0
#        ..
# T       3
# INTC    3
# GILD    3
# GD      1
# ABT     3
# Name: Group, Length: 86, dtype: int32
# 0.972355683304567
# Ticker
# CL     1
# SPG    1
# LLY    5
# AIG    4
# TMO    0
#       ..
# GE     4
# EXC    5
# CAT    4
# ACN    6
# LMT    3
# Name: Group, Length: 86, dtype: int32
# 0.9805085586561597
# Ticker
# GS      1
# TXN     5
# PEP     0
# AMZN    0
# NEE     0
#        ..
# MET     4
# T       5
# UPS     0
# SO      0
# MRK     6
# Name: Group, Length: 86, dtype: int32
# 0.9589801910224481
# Ticker
# AIG     0
# SLB     6
# SO      1
# UNH     1
# HON     3
#        ..
# XOM     6
# MRK     4
# ADBE    3
# PG      1
# RTX     0
# Name: Group, Length: 86, dtype: int32
# 0.9658419784710348
# Ticker
# COF     0
# NVDA    5
# NEE     2
# PEP     2
# BKNG    5
#        ..
# FDX     0
# MO      1
# TGT     4
# GILD    4
# ABT     4
# Name: Group, Length: 86, dtype: int32
# 1.0090266205480818
# Ticker
# MSFT    4
# C       3
# LLY     1
# UNP     2
# TGT     4
#        ..
# SBUX    5
# MCD     5
# BA      3
# FDX     3
# CVX     6
# Name: Group, Length: 86, dtype: int32
# 1.021826271840135
# Ticker
# WMT     3
# FDX     0
# BK      0
# TMO     4
# CL      1
#        ..
# KO      1
# ABT     4
# NVDA    5
# WBA     4
# SO      1
# Name: Group, Length: 86, dtype: int32
# 0.9334821855556841
# Ticker
# C        3
# NVDA     6
# HD       6
# DUK      1
# BRK-B    1
#         ..
# BLK      3
# LOW      5
# MRK      1
# AMT      6
# COF      3
# Name: Group, Length: 86, dtype: int32
# 1.1383133480374024
# Ticker
# PEP      0
# SBUX     0
# WBA      5
# WFC      2
# JNJ      4
#         ..
# CL       0
# CMCSA    5
# BMY      4
# C        6
# UPS      0
# Name: Group, Length: 86, dtype: int32
# 0.9608885559604652
# Ticker
# WBA     1
# MET     4
# MDLZ    3
# JNJ     5
# EXC     5
#        ..
# BLK     6
# GS      6
# XOM     2
# AMGN    5
# KO      3
# Name: Group, Length: 86, dtype: int32
# 0.9832727007109445
# Ticker
# ABT     2
# AAPL    2
# BK      1
# DIS     1
# EXC     5
#        ..
# CVS     5
# INTC    2
# EMR     3
# ADBE    1
# GILD    2
# Name: Group, Length: 86, dtype: int32
# 0.9271720159135317
# Ticker
# KO      4
# INTC    0
# DHR     0
# ALL     5
# FDX     6
#        ..
# ABT     0
# QCOM    0
# CVS     3
# CSCO    0
# COST    3
# Name: Group, Length: 86, dtype: int32
# 1.019300025568581
# Ticker
# GE      5
# DHR     1
# EXC     6
# LLY     6
# SO      0
#        ..
# TXN     1
# BIIB    1
# MCD     0
# NKE     1
# GS      2
# Name: Group, Length: 86, dtype: int32
# 1.013771051482867
# Ticker
# MMM      1
# UNH      5
# RTX      2
# AAPL     1
# WBA      1
#         ..
# CMCSA    1
# BAC      0
# PFE      1
# MS       0
# CAT      2
# Name: Group, Length: 86, dtype: int32
# 1.060526706468551
# Ticker
# TXN      0
# BMY      1
# BIIB     0
# CMCSA    0
# JPM      3
#         ..
# WBA      0
# NVDA     5
# FDX      3
# ALL      4
# HON      3
# Name: Group, Length: 86, dtype: int32
# 0.943268157770058
# Ticker
# MSFT     0
# CL       1
# BRK-B    5
# DD       3
# UNP      2
#         ..
# DUK      5
# COF      3
# BAC      3
# EMR      2
# BK       3
# Name: Group, Length: 86, dtype: int32
# 1.014066040505712
# Ticker
# AMZN    2
# LOW     3
# KO      2
# MSFT    3
# PG      2
#        ..
# CSCO    3
# COP     6
# RTX     1
# AMGN    5
# INTC    3
# Name: Group, Length: 86, dtype: int32
# 0.9625434641004008
# Ticker
# COF      3
# UNH      4
# PG       4
# BKNG     5
# SPG      4
#         ..
# CMCSA    0
# PFE      0
# T        0
# SLB      6
# UNP      1
# Name: Group, Length: 86, dtype: int32
# 0.8544289073765976
# Ticker
# AMZN    1
# CVX     5
# MSFT    0
# GD      6
# EXC     3
#        ..
# ALL     6
# GE      6
# QCOM    0
# BKNG    4
# WBA     0
# Name: Group, Length: 86, dtype: int32
# 0.9205198065997969
# Ticker
# IBM     5
# GS      2
# QCOM    5
# UNP     1
# BLK     2
#        ..
# SPG     0
# GILD    5
# LLY     4
# BMY     4
# OXY     3
# Name: Group, Length: 86, dtype: int32
# 1.0626654312152541
# Ticker
# AXP    4
# SO     3
# PFE    6
# UPS    3
# WBA    6
#       ..
# MS     0
# CL     3
# WFC    4
# NEE    3
# IBM    6
# Name: Group, Length: 86, dtype: int32
# 1.007646792689946
# Ticker
# MCD      2
# NKE      0
# UNP      5
# AXP      5
# MRK      6
#         ..
# BRK-B    6
# TXN      0
# RTX      5
# BIIB     0
# COP      3
# Name: Group, Length: 86, dtype: int32
# 1.0037810755301353
# Ticker
# SO      4
# MS      3
# AXP     0
# AAPL    1
# CL      4
#        ..
# ADBE    3
# MMM     1
# SBUX    4
# T       1
# HD      6
# Name: Group, Length: 86, dtype: int32
# 0.9988244251734752
# Ticker
# DUK     0
# SPG     5
# MO      0
# JNJ     0
# CAT     4
#        ..
# MSFT    1
# MS      3
# WBA     1
# BKNG    6
# AXP     4
# Name: Group, Length: 86, dtype: int32
# 0.9739760936517566
# Ticker
# CL      2
# SBUX    2
# CVX     3
# MMM     4
# QCOM    4
#        ..
# F       0
# ABT     4
# TXN     4
# FDX     0
# LMT     3
# Name: Group, Length: 86, dtype: int32
# 1.022079357864478
# Ticker
# UNP     4
# ORCL    0
# GILD    0
# VZ      1
# CVX     3
#        ..
# MO      1
# COP     3
# BAC     2
# MDT     5
# LMT     3
# Name: Group, Length: 86, dtype: int32
# 0.9232637196132627
# Ticker
# NEE     6
# F       2
# CSCO    0
# MDLZ    6
# AXP     1
#        ..
# LMT     5
# COF     2
# CVS     4
# CVX     5
# WMT     4
# Name: Group, Length: 86, dtype: int32
# 0.9573528624336923
# Ticker
# WFC     6
# TGT     0
# COF     4
# ORCL    0
# PFE     0
#        ..
# MRK     5
# COST    5
# MS      4
# HD      1
# AIG     6
# Name: Group, Length: 86, dtype: int32
# 0.8998974322614705
# Ticker
# JNJ    6
# RTX    1
# LMT    4
# COF    3
# DD     3
#       ..
# WMT    6
# CVX    4
# TXN    5
# AXP    1
# ACN    0
# Name: Group, Length: 86, dtype: int32
# 0.9134604059013458
# Ticker
# INTC    5
# CVS     0
# JNJ     0
# BK      2
# PEP     1
#        ..
# MDT     1
# TXN     5
# MRK     0
# WBA     5
# GILD    5
# Name: Group, Length: 86, dtype: int32
# 1.0404936916226022
# Ticker
# WMT    4
# BAC    0
# JPM    0
# WBA    6
# GD     3
#       ..
# CAT    3
# USB    3
# WFC    3
# MMM    6
# PFE    6
# Name: Group, Length: 86, dtype: int32
# 0.8590546036662065
# Ticker
# JNJ     1
# BA      2
# GE      5
# RTX     5
# NEE     6
#        ..
# SPG     6
# GD      5
# WMT     1
# WFC     5
# AMGN    1
# Name: Group, Length: 86, dtype: int32
# 0.9057560695990876
# Ticker
# KO       0
# AMT      5
# LMT      3
# HON      6
# CSCO     1
#         ..
# ALL      4
# CL       0
# AAPL     1
# BRK-B    2
# PEP      0
# Name: Group, Length: 86, dtype: int32
# 1.012069686432351
# Ticker
# CMCSA    3
# MSFT     3
# BKNG     2
# T        3
# MDT      0
#         ..
# TXN      3
# BIIB     3
# DIS      6
# NKE      3
# AXP      1
# Name: Group, Length: 86, dtype: int32
# 0.958154316770509
# Ticker
# NKE     5
# GS      3
# KO      2
# MDT     2
# INTC    5
#        ..
# ORCL    5
# AMT     1
# LMT     0
# DHR     5
# GD      6
# Name: Group, Length: 86, dtype: int32
# 0.928452740223071
# Ticker
# PEP     4
# ORCL    0
# GD      3
# BK      2
# BKNG    1
#        ..
# CVS     6
# XOM     5
# WBA     0
# COST    6
# UPS     4
# Name: Group, Length: 86, dtype: int32
# 1.040720902803933
# Ticker
# CAT      3
# MDT      5
# SPG      5
# AIG      3
# UNP      3
#         ..
# HON      0
# CSCO     2
# FDX      0
# MCD      5
# BRK-B    1
# Name: Group, Length: 86, dtype: int32
# 0.879631850876507
# Ticker
# UNH     6
# RTX     0
# T       5
# F       3
# BK      3
#        ..
# TMO     5
# GD      0
# AMZN    6
# NVDA    4
# MMM     5
# Name: Group, Length: 86, dtype: int32
# 0.9568155362423507
# Ticker
# MDLZ    4
# AMZN    4
# LOW     6
# PEP     4
# AIG     3
#        ..
# AXP     3
# AAPL    6
# JPM     5
# GILD    6
# DUK     2
# Name: Group, Length: 86, dtype: int32
# 0.8996108136672819
# Ticker
# COF     4
# SPG     2
# FDX     4
# NEE     2
# ACN     6
#        ..
# SLB     1
# WMT     3
# SO      2
# KO      2
# COST    3
# Name: Group, Length: 86, dtype: int32
# 1.045253998604765
# Ticker
# LMT     4
# FDX     0
# COF     0
# UPS     1
# MS      0
#        ..
# NEE     1
# BMY     3
# MRK     3
# CSCO    2
# JPM     0
# Name: Group, Length: 86, dtype: int32
# 0.954301685769727
# Ticker
# XOM     4
# MS      2
# F       2
# JPM     2
# CVS     5
#        ..
# MCD     6
# ADBE    2
# MET     1
# MSFT    0
# OXY     4
# Name: Group, Length: 86, dtype: int32
# 1.0889465596737657
# Ticker
# OXY     3
# AIG     0
# COST    1
# BKNG    4
# ACN     4
#        ..
# XOM     3
# CL      5
# MDLZ    5
# EXC     1
# MRK     1
# Name: Group, Length: 86, dtype: int32
# 0.8731434341689175
# Ticker
# NEE     1
# LMT     0
# KO      1
# EMR     3
# BMY     5
#        ..
# TGT     2
# PG      1
# AIG     3
# MDLZ    1
# USB     3
# Name: Group, Length: 86, dtype: int32
# 0.9569844086921683
# Ticker
# MCD     1
# JPM     6
# EXC     4
# ORCL    3
# SBUX    1
#        ..
# MO      4
# AMZN    1
# SLB     2
# CL      1
# UNH     1
# Name: Group, Length: 86, dtype: int32
# 1.0045638146602465
# Ticker
# AMT     5
# TXN     3
# JNJ     1
# INTC    3
# ALL     6
#        ..
# CSCO    3
# EXC     1
# NVDA    5
# BMY     1
# EMR     6
# Name: Group, Length: 86, dtype: int32
# 1.0022515354094028
# Ticker
# NKE     3
# MET     1
# BKNG    5
# PFE     3
# ALL     1
#        ..
# COP     4
# SBUX    6
# CVS     2
# BK      0
# T       3
# Name: Group, Length: 86, dtype: int32
# 0.9681239173746353
# Ticker
# MMM     0
# BIIB    0
# LOW     0
# DD      1
# USB     5
#        ..
# MO      4
# AMZN    3
# CVS     4
# IBM     0
# OXY     2
# Name: Group, Length: 86, dtype: int32
# 0.9884335110539455
# Ticker
# WMT     1
# TGT     6
# CVS     1
# DIS     2
# CL      3
#        ..
# MSFT    6
# UNP     4
# ACN     5
# F       2
# DHR     6
# Name: Group, Length: 86, dtype: int32
# 0.9499194480468524
# Ticker
# MO      5
# HON     0
# LOW     2
# XOM     4
# LLY     5
#        ..
# AAPL    2
# PEP     3
# UPS     3
# MET     1
# WMT     5
# Name: Group, Length: 86, dtype: int32
# 1.0331212403955203
# Ticker
# WMT     0
# NVDA    5
# UNH     3
# BAC     1
# CL      3
#        ..
# BMY     0
# CVX     4
# UPS     3
# BLK     1
# MO      0
# Name: Group, Length: 86, dtype: int32
# 0.9075482967202214
# Ticker
# JNJ     1
# LOW     4
# TXN     4
# EXC     1
# COST    1
#        ..
# MMM     4
# EMR     0
# HON     2
# OXY     6
# SBUX    3
# Name: Group, Length: 86, dtype: int32
# 0.9844116911107956
# Ticker
# UNP     6
# BK      2
# WMT     0
# NKE     5
# RTX     6
#        ..
# BMY     0
# TXN     5
# DHR     5
# CSCO    5
# PFE     5
# Name: Group, Length: 86, dtype: int32
# 0.9771961554082618
# Ticker
# PFE    2
# C      0
# DD     0
# DIS    0
# MET    4
#       ..
# MDT    6
# TXN    2
# BA     0
# MO     1
# LLY    1
# Name: Group, Length: 86, dtype: int32
# 0.8913626717872453
# Ticker
# BKNG    6
# COST    4
# CAT     2
# SLB     5
# SBUX    1
#        ..
# BA      0
# SO      1
# IBM     3
# BIIB    3
# MMM     3
# Name: Group, Length: 86, dtype: int32
# 0.8781369459212781
# Ticker
# INTC     4
# XOM      2
# FDX      3
# AMT      5
# COP      2
#         ..
# QCOM     4
# BRK-B    1
# JPM      3
# ALL      0
# F        3
# Name: Group, Length: 86, dtype: int32
# 0.945794760512029
# Ticker
# COP     3
# F       4
# COF     4
# SLB     3
# SBUX    2
#        ..
# MDLZ    2
# ACN     6
# TXN     0
# ABT     0
# HD      6
# Name: Group, Length: 86, dtype: int32
# 0.8402109478431281
# Ticker
# VZ      0
# AMZN    4
# MMM     1
# TXN     1
# BAC     3
#        ..
# CAT     6
# XOM     2
# JPM     3
# CSCO    1
# QCOM    1
# Name: Group, Length: 86, dtype: int32
# 0.8754876417932301
# Ticker
# AMT     5
# GILD    6
# XOM     3
# ADBE    2
# VZ      1
#        ..
# FDX     2
# LMT     3
# HD      5
# CVX     3
# UNH     4
# Name: Group, Length: 86, dtype: int32
# 0.9374725752791343
# Ticker
# CSCO     0
# JPM      1
# GS       1
# WMT      4
# ALL      3
#         ..
# FDX      1
# BAC      1
# RTX      3
# BRK-B    4
# MCD      6
# Name: Group, Length: 86, dtype: int32
# 0.937503576087919
# Ticker
# BKNG     4
# BRK-B    5
# GE       2
# SPG      1
# HON      3
#         ..
# CL       1
# CSCO     0
# CAT      2
# QCOM     0
# XOM      6
# Name: Group, Length: 86, dtype: int32
# 1.013279727858836
# Ticker
# AMT    5
# EXC    2
# HD     5
# DD     1
# SLB    3
#       ..
# ABT    0
# PG     6
# JNJ    2
# SPG    6
# IBM    0
# Name: Group, Length: 86, dtype: int32
# 0.8898932498670853
# Ticker
# KO      3
# FDX     1
# JNJ     4
# MET     5
# LLY     4
#        ..
# DHR     6
# ABT     6
# VZ      4
# INTC    6
# COP     0
# Name: Group, Length: 86, dtype: int32
# 1.0029206678229612
# Ticker
# SLB     3
# AAPL    4
# NKE     4
# CVS     1
# LOW     4
#        ..
# BK      2
# CL      6
# XOM     3
# SPG     6
# CAT     0
# Name: Group, Length: 86, dtype: int32
# 0.9025391575558368
# Ticker
# ALL     0
# UNP     0
# GD      0
# QCOM    1
# CAT     0
#        ..
# ADBE    2
# COF     2
# COP     4
# DHR     1
# F       2
# Name: Group, Length: 86, dtype: int32
# 0.8873160862945196
# Ticker
# VZ      0
# KO      2
# FDX     5
# IBM     4
# WFC     1
#        ..
# JNJ     0
# QCOM    4
# INTC    4
# COP     3
# C       5
# Name: Group, Length: 86, dtype: int32
# 0.9304798628412746
# Ticker
# F       4
# IBM     1
# MSFT    1
# JNJ     5
# COP     3
#        ..
# ALL     0
# EXC     5
# CVX     3
# MMM     1
# UNP     0
# Name: Group, Length: 86, dtype: int32
# 0.9500765482021273
# Ticker
# WBA     1
# COP     3
# MDT     6
# QCOM    1
# BK      2
#        ..
# NEE     6
# CSCO    1
# ACN     0
# LMT     3
# AXP     5
# Name: Group, Length: 86, dtype: int32
# 0.9912729826049349
# Ticker
# VZ      2
# ALL     0
# MET     0
# ADBE    1
# CL      5
#        ..
# SO      5
# SLB     4
# JPM     1
# CSCO    6
# CVX     4
# Name: Group, Length: 86, dtype: int32
# 0.9764151192013765
# Ticker
# NEE     1
# MET     4
# HD      6
# CVS     2
# SPG     1
#        ..
# BAC     0
# INTC    5
# DD      0
# BK      0
# NKE     5
# Name: Group, Length: 86, dtype: int32
# 1.0727779259921089
# Ticker
# AMGN    1
# TMO     2
# FDX     3
# INTC    2
# ALL     5
#        ..
# DIS     3
# AAPL    2
# T       2
# DD      3
# GD      5
# Name: Group, Length: 86, dtype: int32
# 0.9733159618536741
# Ticker
# OXY      4
# NEE      3
# F        0
# ADBE     0
# FDX      0
#         ..
# CVX      4
# T        2
# CMCSA    2
# JPM      0
# DIS      0
# Name: Group, Length: 86, dtype: int32
# 1.0199716618917003
# Ticker
# TGT      5
# NEE      0
# GILD     5
# IBM      5
# KO       0
#         ..
# DHR      5
# BKNG     2
# CMCSA    5
# BRK-B    6
# MET      1
# Name: Group, Length: 86, dtype: int32
# 0.9174427166891743
# Ticker
# QCOM    1
# HD      5
# F       6
# LLY     4
# CVS     4
#        ..
# AXP     0
# BA      6
# WBA     1
# XOM     3
# CVX     3
# Name: Group, Length: 86, dtype: int32
# 1.0087594869603491
# Ticker
# BRK-B    1
# UNH      6
# MCD      6
# GD       5
# AXP      5
#         ..
# T        0
# PEP      6
# UNP      5
# TMO      0
# CMCSA    0
# Name: Group, Length: 86, dtype: int32
# 0.982459415168977
# Ticker
# UNH      3
# ADBE     2
# EMR      1
# WMT      5
# GS       2
#         ..
# BRK-B    5
# F        2
# LMT      4
# CSCO     0
# HD       6
# Name: Group, Length: 86, dtype: int32
# 0.9403627680970637
# Ticker
# CAT     1
# MRK     3
# NVDA    2
# COP     5
# MO      3
#        ..
# C       0
# NEE     4
# PFE     6
# JNJ     3
# GILD    6
# Name: Group, Length: 86, dtype: int32
# 1.0100691568471942
# Ticker
# SLB     5
# MSFT    4
# RTX     6
# T       4
# CL      2
#        ..
# QCOM    4
# XOM     5
# WMT     0
# MS      1
# DIS     1
# Name: Group, Length: 86, dtype: int32
# 0.8993029021741279
# Ticker
# ABT     6
# HON     5
# JPM     5
# ADBE    5
# NEE     3
#        ..
# IBM     6
# UNP     1
# PEP     3
# DIS     5
# HD      0
# Name: Group, Length: 86, dtype: int32
# 1.0255659633948289
# Ticker
# T       0
# XOM     3
# DHR     0
# MDLZ    2
# NVDA    4
#        ..
# C       5
# MDT     2
# EMR     1
# SPG     2
# WBA     0
# Name: Group, Length: 86, dtype: int32
# 0.9165780164584686
# Ticker
# AXP     4
# WBA     2
# TMO     2
# MCD     0
# INTC    2
#        ..
# BLK     3
# GS      3
# BMY     1
# HD      6
# MDT     0
# Name: Group, Length: 86, dtype: int32
# 1.0752330235464316
# Ticker
# COF     1
# BIIB    4
# NVDA    3
# BA      1
# TMO     4
#        ..
# BLK     1
# CVS     0
# MCD     5
# QCOM    4
# ALL     6
# Name: Group, Length: 86, dtype: int32
# 1.1717534111368817
# Ticker
# HD      5
# JPM     2
# AIG     3
# FDX     2
# SO      6
#        ..
# AAPL    5
# LLY     1
# SLB     4
# ACN     5
# AMT     5
# Name: Group, Length: 86, dtype: int32
# 1.0168454302886774
# Ticker
# AXP      1
# SLB      4
# USB      1
# LLY      3
# BRK-B    3
#         ..
# AMT      6
# BA       2
# BIIB     6
# CAT      1
# COP      4
# Name: Group, Length: 86, dtype: int32
# 1.0478091198703507
# Ticker
# NEE     0
# LOW     5
# BKNG    1
# NKE     5
# OXY     4
#        ..
# MET     6
# SO      0
# PG      0
# BMY     3
# VZ      3
# Name: Group, Length: 86, dtype: int32
# 0.953038447661422
# Ticker
# C      0
# OXY    4
# WFC    1
# DHR    5
# MMM    5
#       ..
# WMT    3
# IBM    6
# FDX    0
# ACN    6
# NEE    2
# Name: Group, Length: 86, dtype: int32
# 1.2054763319123816
# Ticker
# CL      5
# F       0
# BAC     0
# CAT     6
# RTX     6
#        ..
# CVS     2
# OXY     3
# AXP     6
# BLK     0
# COST    2
# Name: Group, Length: 86, dtype: int32
# 0.9520293001276298
# Ticker
# XOM     5
# MCD     3
# ADBE    2
# DIS     2
# USB     4
#        ..
# IBM     1
# UNP     4
# UPS     3
# KO      3
# ALL     4
# Name: Group, Length: 86, dtype: int32
# 0.9449763869490556
# Ticker
# GS      5
# DUK     0
# BK      5
# WFC     1
# MDLZ    4
#        ..
# NVDA    6
# MS      5
# ACN     6
# PFE     3
# CL      4
# Name: Group, Length: 86, dtype: int32
# 1.060241623875625
# Ticker
# CMCSA    6
# JNJ      4
# GS       3
# BIIB     6
# SBUX     5
#         ..
# MRK      4
# SLB      1
# DUK      4
# NVDA     6
# MDT      5
# Name: Group, Length: 86, dtype: int32
# 1.0919841740973755
# Ticker
# CVX      4
# SLB      4
# GS       6
# BRK-B    5
# WBA      3
#         ..
# MDLZ     2
# DD       6
# T        0
# SPG      2
# BMY      5
# Name: Group, Length: 86, dtype: int32
# 0.9423643292682511
# Ticker
# MRK     1
# BLK     4
# XOM     5
# MMM     6
# COF     4
#        ..
# MSFT    6
# HD      0
# MET     3
# BIIB    0
# PG      2
# Name: Group, Length: 86, dtype: int32
# 1.0463820851995815
# Ticker
# IBM     2
# USB     1
# MRK     5
# ACN     2
# AIG     1
#        ..
# NEE     0
# F       4
# TMO     3
# SPG     0
# INTC    2
# Name: Group, Length: 86, dtype: int32
# 1.0264130403828797
# Ticker
# BLK     4
# MCD     1
# AMGN    0
# NVDA    6
# ADBE    4
#        ..
# PG      1
# DHR     2
# MDT     1
# AMT     6
# AIG     5
# Name: Group, Length: 86, dtype: int32
# 1.1204263090803919
# Ticker
# CMCSA    3
# MMM      6
# IBM      3
# BK       4
# SBUX     0
#         ..
# AMGN     2
# PG       0
# BKNG     3
# JPM      4
# BIIB     3
# Name: Group, Length: 86, dtype: int32
# 0.9761060048815953
# Ticker
# USB     4
# LLY     2
# AAPL    5
# AXP     4
# NVDA    5
#        ..
# MET     4
# BMY     2
# GS      0
# WMT     2
# UPS     1
# Name: Group, Length: 86, dtype: int32
# 1.024072822946041
# Ticker
# CVX     3
# KO      6
# XOM     3
# OXY     3
# AMGN    1
#        ..
# DIS     2
# BIIB    5
# GS      2
# WMT     1
# MS      2
# Name: Group, Length: 86, dtype: int32
# 1.0089731947291398
# Ticker
# RTX     1
# MMM     0
# LLY     4
# DIS     5
# ALL     1
#        ..
# DD      5
# LOW     0
# CL      6
# COST    4
# WFC     1
# Name: Group, Length: 86, dtype: int32
# 0.8960100835112096
# Ticker
# TXN     1
# BK      6
# MDLZ    3
# SPG     3
# VZ      2
#        ..
# T       1
# WFC     0
# ADBE    6
# CL      3
# AXP     0
# Name: Group, Length: 86, dtype: int32
# 1.0405453647767708
# Ticker
# EMR     6
# ADBE    1
# CAT     6
# LMT     2
# WBA     4
#        ..
# GE      6
# MET     6
# EXC     5
# UNP     6
# GS      1
# Name: Group, Length: 86, dtype: int32
# 1.0602248596475914
# Ticker
# AMT     5
# PEP     2
# SLB     3
# SBUX    2
# WFC     6
#        ..
# HD      5
# BK      1
# WBA     0
# UNP     6
# BLK     1
# Name: Group, Length: 86, dtype: int32
# 0.9428605271332577
# Ticker
# COP      0
# BRK-B    3
# OXY      0
# DD       4
# MSFT     1
#         ..
# EMR      2
# T        6
# AIG      2
# LLY      3
# INTC     6
# Name: Group, Length: 86, dtype: int32
# 0.9127870930012926
# Ticker
# QCOM    0
# GS      3
# AMT     1
# COST    5
# MDLZ    6
#        ..
# AIG     2
# BKNG    1
# RTX     2
# GD      2
# KO      6
# Name: Group, Length: 86, dtype: int32
# 1.2071040999847715
# Ticker
# GE      6
# KO      1
# F       3
# TMO     0
# AMGN    2
#        ..
# BAC     3
# BMY     2
# SLB     5
# MO      2
# JPM     3
# Name: Group, Length: 86, dtype: int32
# 1.078332165523013
# Ticker
# HON      6
# MCD      5
# CVS      3
# BMY      3
# WMT      3
#         ..
# C        6
# GS       6
# CMCSA    1
# DHR      0
# KO       5
# Name: Group, Length: 86, dtype: int32
# 1.0115704377516812
# Ticker
# MMM      4
# HON      0
# TGT      1
# TMO      4
# CAT      6
#         ..
# BA       0
# HD       1
# SO       3
# BRK-B    5
# T        1
# Name: Group, Length: 86, dtype: int32
# 1.0573723378012128
# Ticker
# JNJ     5
# CAT     4
# SLB     3
# DIS     1
# ORCL    6
#        ..
# VZ      5
# MET     4
# RTX     4
# LLY     5
# EXC     5
# Name: Group, Length: 86, dtype: int32
# 0.9362801922146945
# Ticker
# GS     0
# XOM    3
# UNH    6
# CL     6
# ACN    4
#       ..
# DHR    2
# MO     5
# COP    3
# BLK    0
# TXN    4
# Name: Group, Length: 86, dtype: int32
# 1.074996282853395
# Ticker
# CSCO    1
# VZ      5
# EMR     4
# BA      0
# GD      4
#        ..
# EXC     5
# COP     2
# LOW     6
# ABT     6
# MS      0
# Name: Group, Length: 86, dtype: int32
# 0.9251944920616454
# Ticker
# SBUX     2
# GD       4
# AMZN     2
# GILD     5
# UNH      2
#         ..
# PG       2
# BRK-B    1
# MO       1
# WFC      4
# INTC     6
# Name: Group, Length: 86, dtype: int32
# 1.0723570582577433
# Ticker
# DD      1
# C       1
# PG      6
# XOM     3
# USB     0
#        ..
# BKNG    5
# MSFT    2
# MCD     6
# ADBE    1
# MET     0
# Name: Group, Length: 86, dtype: int32
# 1.0387350739922467
# Ticker
# RTX     0
# EMR     0
# BLK     2
# MDLZ    4
# MRK     3
#        ..
# COF     2
# GE      0
# CVS     3
# ACN     1
# ABT     6
# Name: Group, Length: 86, dtype: int32
# 1.029833156358989
# Ticker
# ABT     2
# GS      3
# QCOM    2
# CAT     0
# KO      6
#        ..
# DUK     1
# MET     0
# EXC     1
# CVS     1
# SBUX    6
# Name: Group, Length: 86, dtype: int32
# 0.9237283791944815
# Ticker
# GILD    2
# CAT     5
# UNH     3
# ADBE    6
# KO      3
#        ..
# WBA     2
# EMR     5
# AMT     1
# UPS     3
# WFC     5
# Name: Group, Length: 86, dtype: int32
# 1.160978525897965
# Ticker
# QCOM    1
# C       2
# T       3
# AMT     3
# HD      3
#        ..
# ORCL    1
# BKNG    3
# MRK     4
# AMGN    4
# DD      2
# Name: Group, Length: 86, dtype: int32
# 1.0035423762047995
# Ticker
# COST    1
# AMT     3
# CSCO    3
# SBUX    2
# BA      5
#        ..
# BAC     5
# HON     5
# LOW     0
# WBA     0
# FDX     5
# Name: Group, Length: 86, dtype: int32
# 1.0728683942592332
# Ticker
# SPG     6
# AAPL    0
# ACN     0
# TMO     1
# EXC     4
#        ..
# BIIB    0
# MDT     6
# HON     5
# VZ      4
# MSFT    1
# Name: Group, Length: 86, dtype: int32
# 1.0431129032790165
# Ticker
# SPG     1
# MDLZ    1
# NKE     5
# AMGN    6
# VZ      6
#        ..
# DUK     6
# F       3
# AAPL    0
# TXN     0
# AMT     0
# Name: Group, Length: 86, dtype: int32
# 0.9941392318765503
# Ticker
# VZ       6
# BLK      2
# DD       2
# PEP      4
# BRK-B    6
#         ..
# NVDA     0
# CVS      6
# QCOM     1
# CL       4
# GE       5
# Name: Group, Length: 86, dtype: int32
# 1.0273398974953187
# Ticker
# VZ      5
# ADBE    2
# COF     2
# OXY     4
# MDLZ    3
#        ..
# MDT     3
# RTX     0
# GE      0
# LOW     6
# CAT     0
# Name: Group, Length: 86, dtype: int32
# 0.9412007668153469
# Ticker
# JNJ    0
# JPM    4
# ABT    6
# DIS    4
# C      4
#       ..
# PFE    6
# CVX    3
# SLB    3
# NEE    5
# PG     5
# Name: Group, Length: 86, dtype: int32
# 1.0120069592241534
# Ticker
# UNP      0
# GE       0
# MDT      1
# AIG      0
# C        5
#         ..
# NVDA     4
# XOM      3
# BRK-B    2
# CAT      0
# QCOM     6
# Name: Group, Length: 86, dtype: int32
# 1.1005330492770347
# Ticker
# NEE     2
# FDX     5
# ACN     1
# PEP     2
# WMT     6
#        ..
# C       5
# IBM     1
# COST    6
# MCD     2
# BIIB    1
# Name: Group, Length: 86, dtype: int32
# 1.046680794258258
# Ticker
# AXP     3
# MSFT    6
# KO      1
# UNH     1
# AMZN    1
#        ..
# TGT     5
# OXY     2
# AMT     5
# WMT     4
# JPM     0
# Name: Group, Length: 86, dtype: int32
# 1.0307202725782405
# Ticker
# PFE     1
# VZ      4
# BLK     2
# TMO     1
# COF     2
#        ..
# MMM     1
# CSCO    5
# COST    4
# RTX     3
# MRK     4
# Name: Group, Length: 86, dtype: int32
# 1.075080712661712
# Ticker
# BAC     6
# NEE     5
# COST    3
# QCOM    1
# JNJ     3
#        ..
# UNP     2
# PEP     5
# GILD    1
# XOM     4
# RTX     2
# Name: Group, Length: 86, dtype: int32
# 0.9994084920337629
# Ticker
# DUK     2
# LOW     0
# T       5
# GS      3
# RTX     4
#        ..
# BMY     2
# MSFT    0
# ORCL    0
# GE      4
# WFC     4
# Name: Group, Length: 86, dtype: int32
# 1.128369281362567
# Ticker
# BKNG    1
# F       2
# TGT     1
# MRK     4
# INTC    1
#        ..
# AIG     6
# MMM     3
# ACN     1
# HON     2
# T       1
# Name: Group, Length: 86, dtype: int32
# 0.983627939197712
# Ticker
# UNP     5
# IBM     3
# BIIB    3
# TXN     3
# JPM     0
#        ..
# MRK     2
# UNH     4
# BLK     0
# ADBE    0
# AMGN    2
# Name: Group, Length: 86, dtype: int32
# 0.9070413127713611
# Ticker
# NEE     5
# GILD    1
# UPS     5
# ABT     1
# MMM     1
#        ..
# HD      6
# XOM     2
# USB     4
# BA      3
# LLY     0
# Name: Group, Length: 86, dtype: int32
# 0.9872242179462586
# Ticker
# USB     5
# LMT     3
# C       2
# WFC     5
# DHR     6
#        ..
# NEE     4
# BKNG    0
# UNH     4
# AMZN    4
# GE      5
# Name: Group, Length: 86, dtype: int32
# 0.9323863120151957
# Ticker
# UNH     2
# AMZN    2
# BK      1
# KO      2
# EXC     3
#        ..
# WFC     4
# XOM     5
# GS      1
# NVDA    6
# MSFT    0
# Name: Group, Length: 86, dtype: int32
# 1.0049777006662235
# Ticker
# WBA    5
# NEE    0
# DUK    6
# MMM    5
# TGT    3
#       ..
# BMY    6
# LLY    6
# BA     2
# IBM    3
# DHR    5
# Name: Group, Length: 86, dtype: int32
# 0.9874700068541804
# Ticker
# MDT     3
# F       2
# BLK     2
# MRK     5
# MSFT    0
#        ..
# TMO     0
# LOW     0
# NKE     0
# GD      1
# C       2
# Name: Group, Length: 86, dtype: int32
# 0.9708593752382713
# Ticker
# WMT     6
# AMZN    2
# WFC     1
# TMO     3
# GILD    3
#        ..
# GD      1
# NKE     3
# USB     1
# DUK     6
# ADBE    5
# Name: Group, Length: 86, dtype: int32
# 0.9198769902769265
# Ticker
# WMT     3
# COP     4
# USB     2
# EXC     3
# QCOM    6
#        ..
# SLB     4
# BIIB    0
# OXY     4
# WFC     2
# GILD    6
# Name: Group, Length: 86, dtype: int32
# 1.0771738294589603
# Ticker
# AAPL    5
# LLY     2
# HD      5
# EXC     2
# AXP     1
#        ..
# ORCL    0
# DD      6
# SPG     4
# SLB     3
# WMT     2
# Name: Group, Length: 86, dtype: int32
# 0.9420846583359819
# Ticker
# COF      4
# CMCSA    5
# CL       1
# KO       1
# TGT      5
#         ..
# MCD      1
# F        4
# MSFT     3
# SBUX     1
# SO       1
# Name: Group, Length: 86, dtype: int32
# 1.1118397202606503
# Ticker
# ADBE    0
# BK      0
# GILD    4
# SO      5
# WBA     4
#        ..
# COST    1
# EXC     1
# BLK     0
# UNP     3
# AXP     3
# Name: Group, Length: 86, dtype: int32
# 0.9925711755898227
# Ticker
# ORCL    5
# LLY     0
# PG      6
# BIIB    1
# CVX     4
#        ..
# ACN     1
# AAPL    1
# GE      2
# MRK     0
# BAC     3
# Name: Group, Length: 86, dtype: int32
# 1.0756010652784866
# Ticker
# BA      1
# DD      1
# SBUX    3
# UPS     3
# MMM     4
#        ..
# MRK     2
# TMO     4
# CAT     5
# MSFT    4
# AMGN    2
# Name: Group, Length: 86, dtype: int32
# 1.0280048056276672
# Ticker
# KO       4
# ORCL     0
# TXN      3
# BLK      1
# UNP      6
#         ..
# CVS      5
# BRK-B    5
# VZ       5
# NEE      4
# BK       1
# Name: Group, Length: 86, dtype: int32
# 1.045409821555167
# Ticker
# PFE      1
# EXC      6
# PEP      5
# GD       0
# JPM      4
#         ..
# ADBE     4
# PG       5
# AMT      3
# CMCSA    3
# COP      2
# Name: Group, Length: 86, dtype: int32
# 1.0399621149669518
# Ticker
# DUK     0
# HON     2
# OXY     3
# COST    0
# WMT     0
#        ..
# SO      6
# EXC     0
# DD      2
# GILD    5
# BK      2
# Name: Group, Length: 86, dtype: int32
# 1.1131623737932346
# Ticker
# MSFT    1
# BKNG    3
# AMT     3
# BAC     0
# GILD    1
#        ..
# PG      6
# PFE     1
# CAT     5
# ALL     5
# XOM     4
# Name: Group, Length: 86, dtype: int32
# 0.9645268713679968
# Ticker
# XOM     2
# BMY     6
# ALL     1
# BIIB    3
# COST    6
#        ..
# TGT     3
# USB     1
# C       4
# JPM     4
# BK      4
# Name: Group, Length: 86, dtype: int32
# 1.0447364529037766
# Ticker
# DIS     6
# HON     6
# DD      6
# LLY     3
# NVDA    1
#        ..
# MRK     3
# BA      6
# SPG     5
# BK      6
# SBUX    5
# Name: Group, Length: 86, dtype: int32
# 0.9924781685399504
# Ticker
# TGT     0
# ACN     0
# XOM     3
# KO      4
# WMT     6
#        ..
# ADBE    1
# COST    6
# MO      6
# GS      1
# QCOM    5
# Name: Group, Length: 86, dtype: int32
# 1.1246510519138113
# Ticker
# CSCO    0
# FDX     5
# ACN     0
# EMR     4
# DUK     1
#        ..
# ALL     4
# DIS     5
# MS      5
# F       5
# LMT     2
# Name: Group, Length: 86, dtype: int32
# 0.9412372174187043
# Ticker
# JPM    1
# MDT    4
# UPS    4
# IBM    2
# MRK    0
#       ..
# BLK    1
# LMT    3
# HON    1
# COP    3
# CAT    6
# Name: Group, Length: 86, dtype: int32
# 1.0461898828957128
# Ticker
# IBM     3
# PG      0
# UNH     0
# HON     1
# ORCL    5
#        ..
# TMO     5
# ALL     2
# CL      0
# MET     2
# DHR     5
# Name: Group, Length: 86, dtype: int32
# 0.9727069591488794
# Ticker
# AAPL    6
# GD      0
# PFE     4
# AMZN    5
# BK      1
#        ..
# PG      5
# DD      1
# TMO     4
# EXC     2
# SPG     5
# Name: Group, Length: 86, dtype: int32
# 1.0433443485124765
# Ticker
# PFE     3
# GS      0
# CSCO    1
# EMR     5
# VZ      4
#        ..
# GD      5
# BA      0
# NVDA    1
# GE      5
# TMO     3
# Name: Group, Length: 86, dtype: int32
# 0.9499559464209649
# Ticker
# MMM    1
# DD     6
# CVS    0
# VZ     0
# AXP    5
#       ..
# FDX    6
# F      6
# GS     6
# BMY    0
# WMT    0
# Name: Group, Length: 86, dtype: int32
# 0.9647808484961864
# Ticker
# HON     5
# SO      4
# AMT     2
# C       5
# TXN     2
#        ..
# MO      0
# NEE     4
# INTC    2
# CSCO    2
# IBM     2
# Name: Group, Length: 86, dtype: int32
# 0.9576281001374741
# Ticker
# MCD      0
# UPS      0
# ACN      4
# AXP      2
# CMCSA    4
#         ..
# AMZN     1
# BRK-B    3
# FDX      6
# PG       0
# OXY      5
# Name: Group, Length: 86, dtype: int32
# 1.036717433747038
# Ticker
# AMZN     0
# CSCO     2
# COST     4
# MSFT     0
# IBM      2
#         ..
# AMGN     4
# AMT      2
# TMO      0
# DIS      1
# BRK-B    4
# Name: Group, Length: 86, dtype: int32
# 0.9978050683524259
# Ticker
# BAC      5
# CMCSA    3
# BKNG     3
# TXN      3
# MMM      0
#         ..
# COF      5
# MRK      2
# AMT      3
# IBM      3
# NEE      1
# Name: Group, Length: 86, dtype: int32
# 1.1053080252846461
# Ticker
# PEP      5
# WBA      0
# CMCSA    6
# OXY      3
# MCD      5
#         ..
# JNJ      1
# QCOM     0
# AMT      6
# SBUX     5
# MRK      1
# Name: Group, Length: 86, dtype: int32
# 0.9618640134898967
# Ticker
# SPG     6
# TMO     1
# LOW     1
# F       2
# ALL     5
#        ..
# BIIB    0
# LLY     4
# CL      6
# UNP     5
# BAC     2
# Name: Group, Length: 86, dtype: int32
# 1.0257229293641086
# Ticker
# LMT     3
# HD      5
# MCD     6
# BKNG    5
# TGT     5
#        ..
# COP     3
# PFE     1
# C       2
# UNP     0
# PEP     6
# Name: Group, Length: 86, dtype: int32
# 0.9541464702080188
# Ticker
# USB     1
# BA      6
# PFE     3
# AMGN    5
# SO      4
#        ..
# QCOM    3
# TMO     3
# VZ      5
# TGT     0
# MDT     4
# Name: Group, Length: 86, dtype: int32
# 1.023067035138228
# Ticker
# AIG     5
# AMT     0
# ABT     6
# MET     5
# DD      3
#        ..
# ALL     5
# AXP     5
# SLB     2
# CSCO    0
# MS      3
# Name: Group, Length: 86, dtype: int32
# 0.9017569059495567
# Ticker
# TXN     4
# AXP     0
# USB     0
# INTC    4
# PEP     6
#        ..
# GILD    5
# CSCO    4
# DD      3
# QCOM    5
# NKE     5
# Name: Group, Length: 86, dtype: int32
# 1.1150471826985207
# Ticker
# XOM     0
# CVX     0
# ALL     5
# MDLZ    4
# ABT     6
#        ..
# SO      4
# DUK     2
# INTC    1
# GE      5
# CSCO    1
# Name: Group, Length: 86, dtype: int32
# 0.8963313042697415
# Ticker
# HON     2
# UNP     1
# XOM     5
# DIS     2
# ADBE    2
#        ..
# SLB     5
# MDT     6
# WFC     1
# JNJ     0
# UPS     6
# Name: Group, Length: 86, dtype: int32
# 1.0676172644127335
# Ticker
# TGT    4
# DD     3
# MS     3
# EMR    6
# KO     5
#       ..
# MMM    0
# GE     6
# MRK    1
# CAT    6
# MDT    5
# Name: Group, Length: 86, dtype: int32
# 0.9771393284942789
# Ticker
# WBA    0
# JNJ    2
# MDT    5
# DD     3
# LLY    2
#       ..
# PG     5
# DUK    2
# EMR    1
# SO     5
# GS     3
# Name: Group, Length: 86, dtype: int32
# 0.9650122548524223
# Ticker
# AXP     5
# QCOM    0
# TGT     6
# BIIB    6
# COST    3
#        ..
# LLY     3
# ALL     5
# MDLZ    2
# SLB     1
# GD      5
# Name: Group, Length: 86, dtype: int32
# 1.0397261251867838
# Ticker
# MDLZ    6
# LOW     1
# CAT     0
# JNJ     3
# BK      5
#        ..
# ALL     0
# C       5
# UNP     0
# EMR     0
# BKNG    4
# Name: Group, Length: 86, dtype: int32
# 0.9797165010878578
# Ticker
# GS      1
# UNP     4
# AXP     4
# UNH     5
# GE      4
#        ..
# ADBE    1
# EXC     6
# TGT     3
# BLK     1
# MDLZ    5
# Name: Group, Length: 86, dtype: int32
# 1.1465596335584611
# Ticker
# CVX     2
# MO      1
# BIIB    5
# ORCL    4
# F       0
#        ..
# VZ      1
# QCOM    4
# NVDA    5
# LLY     1
# PFE     4
# Name: Group, Length: 86, dtype: int32
# 0.9514308294377118
# Ticker
# NVDA    6
# WMT     3
# OXY     4
# XOM     4
# FDX     2
#        ..
# CAT     0
# COP     4
# JNJ     3
# USB     0
# LMT     4
# Name: Group, Length: 86, dtype: int32
# 0.9268088310764158
# Ticker
# USB     4
# WFC     4
# SPG     2
# PFE     3
# MS      0
#        ..
# ACN     6
# F       0
# GE      4
# BIIB    6
# AIG     4
# Name: Group, Length: 86, dtype: int32
# 0.9596736465920238
# Ticker
# UNP     6
# PG      5
# MRK     0
# QCOM    3
# WBA     3
#        ..
# SPG     5
# AMT     2
# LLY     0
# BA      1
# UNH     5
# Name: Group, Length: 86, dtype: int32
# 1.024130815399941
# Ticker
# BMY     3
# ABT     6
# NEE     5
# ORCL    6
# SBUX    5
#        ..
# LLY     3
# CSCO    0
# SO      5
# CVX     4
# GE      1
# Name: Group, Length: 86, dtype: int32
# 1.042878188039549
# Ticker
# BA     3
# GE     5
# HON    3
# DD     3
# MMM    1
#       ..
# XOM    4
# GD     5
# COP    4
# WMT    2
# SLB    4
# Name: Group, Length: 86, dtype: int32
# 1.0015330450008686
# Ticker
# GILD    1
# AMT     6
# GS      2
# UNH     0
# JNJ     5
#        ..
# TXN     6
# UPS     0
# SLB     3
# AMZN    1
# PFE     1
# Name: Group, Length: 86, dtype: int32
# 1.0471903152547781
# Ticker
# PG      6
# AMZN    1
# LOW     1
# SBUX    6
# UNH     6
#        ..
# EXC     4
# BAC     5
# JPM     5
# MSFT    1
# HON     5
# Name: Group, Length: 86, dtype: int32
# 1.016709143015925
# Ticker
# AIG      1
# MDLZ     3
# LLY      4
# UPS      3
# CMCSA    2
#         ..
# ORCL     6
# KO       3
# VZ       4
# UNP      1
# COST     4
# Name: Group, Length: 86, dtype: int32
# 1.043114912193322
# Ticker
# MSFT    0
# COP     3
# LOW     0
# BIIB    4
# ADBE    5
#        ..
# GE      1
# MS      5
# NKE     0
# UNP     1
# AMGN    6
# Name: Group, Length: 86, dtype: int32
# 0.9061222366716024
# Ticker
# PG      2
# ALL     3
# BKNG    6
# QCOM    1
# CSCO    6
#        ..
# GS      0
# SLB     5
# IBM     6
# TXN     6
# INTC    6
# Name: Group, Length: 86, dtype: int32
# 0.987749591399539
# Ticker
# XOM      5
# LLY      1
# BRK-B    1
# EXC      1
# DHR      6
#         ..
# GS       4
# MMM      6
# MCD      0
# MET      2
# JPM      4
# Name: Group, Length: 86, dtype: int32
# 1.0211226047471686
# Ticker
# BLK      5
# XOM      2
# LOW      1
# PFE      1
# CMCSA    3
#         ..
# COF      5
# OXY      2
# MCD      0
# SLB      2
# COP      2
# Name: Group, Length: 86, dtype: int32
# 1.1101000892669572
# Ticker
# NKE     4
# JPM     0
# SO      2
# USB     3
# LMT     1
#        ..
# EXC     5
# AAPL    6
# DHR     4
# MS      0
# CVX     1
# Name: Group, Length: 86, dtype: int32
# 0.9300920255491194
# Ticker
# LOW     5
# INTC    0
# NVDA    0
# AMT     0
# AXP     1
#        ..
# NKE     5
# LLY     4
# WBA     5
# T       0
# NEE     6
# Name: Group, Length: 86, dtype: int32
# 1.0554294197737784
# Ticker
# WBA      6
# UNH      5
# CMCSA    2
# NKE      6
# BK       0
#         ..
# ACN      2
# UPS      5
# WMT      1
# BKNG     2
# SO       5
# Name: Group, Length: 86, dtype: int32
# 1.0062962681112793
# Ticker
# NVDA    0
# IBM     0
# PG      6
# AIG     2
# ABT     1
#        ..
# MSFT    1
# USB     2
# VZ      5
# BKNG    0
# ORCL    1
# Name: Group, Length: 86, dtype: int32
# 1.0946184539936537
# Ticker
# MS       4
# AMT      2
# BIIB     2
# CMCSA    2
# RTX      0
#         ..
# COP      3
# NVDA     2
# F        4
# COST     1
# SBUX     6
# Name: Group, Length: 86, dtype: int32
# 1.008059000411341
# Ticker
# USB      4
# ORCL     6
# COP      0
# BRK-B    5
# NEE      3
#         ..
# BMY      5
# CSCO     2
# OXY      0
# FDX      1
# BKNG     2
# Name: Group, Length: 86, dtype: int32
# 0.974042638079529
# Ticker
# NKE     6
# UPS     1
# BMY     2
# CSCO    3
# IBM     3
#        ..
# DUK     2
# DD      0
# TGT     3
# USB     5
# CAT     5
# Name: Group, Length: 86, dtype: int32
# 0.9749383704500797
# Ticker
# BMY     0
# CAT     4
# VZ      0
# MMM     1
# CSCO    5
#        ..
# WMT     0
# ABT     1
# PEP     6
# SPG     6
# ORCL    1
# Name: Group, Length: 86, dtype: int32
# 0.9768705849432405
# Ticker
# BMY     4
# WMT     4
# BKNG    5
# AAPL    5
# AIG     3
#        ..
# MDT     2
# MS      0
# CVS     4
# ABT     6
# EXC     4
# Name: Group, Length: 86, dtype: int32
# 1.005383081000714
# Ticker
# CSCO    4
# GD      0
# UNH     1
# BMY     2
# LMT     6
#        ..
# ABT     5
# C       3
# COST    2
# AAPL    4
# MCD     1
# Name: Group, Length: 86, dtype: int32
# 1.1309796107724444
# Ticker
# LOW     0
# QCOM    0
# DD      6
# JNJ     3
# CVX     2
#        ..
# CVS     3
# BAC     6
# DIS     6
# BK      6
# TGT     5
# Name: Group, Length: 86, dtype: int32
# 1.0722401775931043
# Ticker
# MDLZ    2
# GD      5
# XOM     3
# PFE     1
# HD      0
#        ..
# AMT     0
# BLK     6
# AXP     5
# BAC     6
# BIIB    0
# Name: Group, Length: 86, dtype: int32
# 1.1506981474174725
# Ticker
# PG      0
# PEP     0
# LLY     2
# AMZN    5
# AMT     3
#        ..
# SLB     4
# COF     1
# AAPL    3
# COP     4
# HD      3
# Name: Group, Length: 86, dtype: int32
# 0.921285245027998
# Ticker
# BA      2
# BK      2
# HD      5
# UNH     6
# MSFT    4
#        ..
# ACN     5
# PEP     6
# BIIB    5
# ADBE    2
# FDX     2
# Name: Group, Length: 86, dtype: int32
# 1.0853830437299952
# Ticker
# BAC     3
# SPG     4
# BLK     3
# TXN     1
# ADBE    3
#        ..
# VZ      2
# UNP     6
# GE      6
# PFE     5
# NVDA    1
# Name: Group, Length: 86, dtype: int32
# 0.9915087039505861
# Ticker
# TMO    6
# BK     2
# MET    0
# FDX    2
# AIG    0
#       ..
# DIS    2
# WMT    3
# SLB    4
# XOM    4
# DD     2
# Name: Group, Length: 86, dtype: int32
# 1.057506697980544
# Ticker
# UNH     6
# MSFT    0
# DUK     2
# DHR     0
# CVS     2
#        ..
# MO      2
# COST    2
# MET     5
# INTC    1
# COF     4
# Name: Group, Length: 86, dtype: int32
# 1.0730647457454194
# Ticker
# XOM     2
# OXY     2
# BA      6
# GE      1
# ACN     0
#        ..
# SO      4
# MET     1
# INTC    0
# AMGN    3
# COP     2
# Name: Group, Length: 86, dtype: int32
# 1.0914589082292847
# Ticker
# TGT      5
# VZ       4
# LOW      0
# ADBE     6
# QCOM     0
#         ..
# BKNG     5
# F        6
# GS       6
# ACN      5
# CMCSA    5
# Name: Group, Length: 86, dtype: int32
# 0.9855796171065391
# Ticker
# LOW      1
# AMT      5
# BIIB     5
# XOM      3
# CMCSA    5
#         ..
# VZ       0
# COP      3
# WMT      0
# SPG      4
# NEE      4
# Name: Group, Length: 86, dtype: int32
# 0.9841780452415901
# Ticker
# BK      6
# UPS     3
# PEP     3
# GILD    4
# MSFT    4
#        ..
# LOW     4
# LLY     0
# PG      3
# MDLZ    3
# ACN     1
# Name: Group, Length: 86, dtype: int32
# 1.10697764522565
# Ticker
# UPS     6
# GILD    0
# EMR     5
# EXC     1
# TXN     3
#        ..
# INTC    3
# IBM     3
# T       3
# ACN     3
# BLK     2
# Name: Group, Length: 86, dtype: int32
# 1.0332862271479992
# Ticker
# MDLZ    5
# TMO     2
# CVS     6
# AMGN    6
# PFE     2
#        ..
# TGT     4
# BMY     6
# RTX     0
# GE      0
# DHR     2
# Name: Group, Length: 86, dtype: int32
# 1.081302823231456
# Ticker
# COF     1
# UPS     5
# SBUX    5
# MO      4
# BLK     1
#        ..
# ADBE    1
# GD      6
# MCD     5
# KO      5
# BAC     1
# Name: Group, Length: 86, dtype: int32
# 1.0226749501701458
# Ticker
# FDX     6
# GILD    5
# DIS     6
# VZ      4
# LMT     0
#        ..
# WMT     4
# SLB     0
# JNJ     4
# AIG     2
# BKNG    1
# Name: Group, Length: 86, dtype: int32
# 1.0232934097303967
# Ticker
# LOW    5
# DUK    0
# USB    6
# TGT    3
# T      3
#       ..
# HON    2
# CVX    4
# WBA    5
# BAC    2
# WFC    6
# Name: Group, Length: 86, dtype: int32
# 1.0714727233728465
# Ticker
# CMCSA    0
# UPS      6
# QCOM     4
# SLB      3
# CVX      3
#         ..
# T        0
# NEE      6
# RTX      1
# BMY      2
# NKE      4
# Name: Group, Length: 86, dtype: int32
# 0.944188293247597
# Ticker
# NKE     2
# TMO     2
# AMGN    3
# AXP     1
# GD      1
#        ..
# NEE     0
# WMT     3
# PG      0
# GS      6
# LMT     5
# Name: Group, Length: 86, dtype: int32
# 0.9198722503449729
# Ticker
# CSCO    1
# LOW     6
# TGT     1
# COP     4
# BLK     3
#        ..
# SLB     4
# PG      5
# GS      3
# AIG     2
# CAT     2
# Name: Group, Length: 86, dtype: int32
# 1.1200380807724246
# Ticker
# BRK-B    2
# AAPL     5
# KO       0
# PG       0
# COF      6
#         ..
# LLY      2
# NKE      4
# VZ       2
# AMGN     2
# DD       6
# Name: Group, Length: 86, dtype: int32
# 1.0509152733395017
# Ticker
# BKNG    1
# SO      4
# ACN     1
# EXC     6
# NVDA    1
#        ..
# CVX     2
# GE      0
# XOM     2
# QCOM    5
# JNJ     6
# Name: Group, Length: 86, dtype: int32
# 1.0430336942748037
# Ticker
# LMT     2
# TXN     6
# IBM     6
# SO      0
# WMT     4
#        ..
# EMR     1
# DHR     5
# TMO     5
# MDLZ    0
# ACN     6
# Name: Group, Length: 86, dtype: int32
# 0.9916857416729438
# Ticker
# MS      2
# EMR     0
# DIS     2
# CSCO    1
# USB     0
#        ..
# BAC     2
# AMZN    6
# WBA     6
# C       2
# COF     2
# ...
# DHR     6
# ALL     5
# BA      0
#        ..
# C       0
# MRK     3
# MSFT    6
# MDLZ    2
# DIS     0
# Name: Group, Length: 86, dtype: int32
# 0.9938523574404723
# Ticker
# DD      0
# BA      0
# CSCO    4
# CL      2
# CVS     1
#        ..
# MO      1
# PG      2
# MS      0
# AAPL    4
# C       0
# Name: Group, Length: 86, dtype: int32
# 0.9775380807431883
# Ticker
# CAT     1
# IBM     5
# GE      1
# BLK     0
# EXC     3
#        ..
# QCOM    2
# PG      6
# TXN     5
# JNJ     3
# NEE     6
# Name: Group, Length: 86, dtype: int32
# 1.0028433987149652
# Ticker
# WFC     1
# PG      2
# AIG     1
# GE      1
# GS      6
#        ..
# ORCL    4
# AXP     1
# ABT     4
# UPS     2
# JNJ     3
# Name: Group, Length: 86, dtype: int32
# 0.9652714241141785
# Ticker
# SPG    6
# COP    4
# GD     5
# CVX    4
# MET    5
#       ..
# BLK    1
# BMY    3
# WFC    5
# COF    1
# ALL    5
# Name: Group, Length: 86, dtype: int32
# 0.9962479000697562
# Ticker
# ACN     4
# SLB     5
# LLY     6
# KO      3
# ADBE    4
#        ..
# PEP     3
# UNP     2
# CAT     2
# DD      1
# NKE     4
# Name: Group, Length: 86, dtype: int32
# 0.9635015717875502
# Ticker
# CL       1
# BLK      4
# PEP      1
# ACN      6
# BRK-B    3
#         ..
# AMZN     1
# NKE      6
# CAT      2
# LOW      1
# TGT      6
# Name: Group, Length: 86, dtype: int32
# 0.9032688038676123
# Ticker
# COST    6
# OXY     4
# KO      2
# NEE     2
# GE      5
#        ..
# RTX     5
# C       3
# MMM     0
# WBA     0
# EMR     5
# Name: Group, Length: 86, dtype: int32
# 1.0400592204572026
# Ticker
# CAT     1
# AIG     1
# SO      5
# AAPL    6
# USB     1
#        ..
# COF     2
# TMO     0
# BA      2
# NEE     5
# BMY     3
# Name: Group, Length: 86, dtype: int32
# 0.9706478312099633
# Ticker
# SBUX    6
# TMO     5
# KO      6
# ACN     1
# USB     3
#        ..
# MCD     4
# AAPL    1
# BIIB    5
# CVX     2
# GD      3
# Name: Group, Length: 86, dtype: int32
# 1.029281644146611
# Ticker
# BK      6
# TGT     1
# AAPL    1
# NVDA    1
# MRK     0
#        ..
# HON     6
# LLY     0
# ABT     2
# HD      1
# CAT     5
# Name: Group, Length: 86, dtype: int32
# 1.0606222452762915
# Ticker
# TGT     1
# DIS     0
# DUK     5
# BK      0
# BKNG    1
#        ..
# BMY     5
# TMO     6
# KO      2
# PG      2
# MS      0
# Name: Group, Length: 86, dtype: int32
# 1.0176836507097597
# Ticker
# RTX     2
# EXC     0
# HON     3
# GILD    4
# EMR     2
#        ..
# SPG     1
# PEP     1
# NKE     5
# WBA     4
# KO      1
# Name: Group, Length: 86, dtype: int32
# 1.155824008937148
# Ticker
# GD      0
# TGT     2
# IBM     2
# TXN     2
# AXP     0
#        ..
# COP     1
# T       2
# AMGN    6
# UPS     4
# AAPL    2
# Name: Group, Length: 86, dtype: int32
# 1.0233211782885545
# Ticker
# LLY     2
# FDX     5
# JPM     5
# INTC    0
# UNP     3
#        ..
# NKE     0
# PFE     4
# KO      1
# COP     6
# AMZN    1
# Name: Group, Length: 86, dtype: int32
# 1.027538333014292
# Ticker
# BAC      0
# MS       0
# UPS      6
# BMY      3
# LOW      6
#         ..
# CVX      5
# MRK      3
# MDT      6
# CMCSA    1
# UNH      6
# Name: Group, Length: 86, dtype: int32
# 0.9413783046785565
# Ticker
# SBUX    3
# BIIB    0
# COST    5
# ORCL    0
# ADBE    4
#        ..
# GE      1
# AMZN    3
# VZ      5
# WFC     1
# USB     1
# Name: Group, Length: 86, dtype: int32
# 0.8963087714127767
# Ticker
# ALL     1
# CSCO    3
# EXC     0
# PFE     5
# DD      2
#        ..
# C       2
# NEE     6
# CVS     0
# AIG     1
# AMZN    6
# Name: Group, Length: 86, dtype: int32
# 1.0494700971750028
# Ticker
# AMGN     5
# HD       0
# KO       2
# ADBE     0
# AAPL     0
#         ..
# DHR      6
# BKNG     0
# BRK-B    5
# OXY      3
# CVS      5
# Name: Group, Length: 86, dtype: int32
# 0.8942505218892449
# Ticker
# LMT    6
# SLB    6
# LLY    5
# TXN    3
# COF    2
#       ..
# IBM    3
# WBA    1
# MS     2
# MET    4
# MCD    5
# Name: Group, Length: 86, dtype: int32
# 1.0230785588645894
# Ticker
# SPG     2
# FDX     4
# LMT     3
# INTC    6
# LOW     2
#        ..
# AXP     0
# AMT     6
# TGT     6
# ORCL    1
# MET     0
# Name: Group, Length: 86, dtype: int32
# 0.9704759692223933
# Ticker
# MCD    6
# AIG    5
# PFE    4
# UPS    1
# MO     6
#       ..
# COF    2
# CVX    0
# HON    2
# RTX    5
# VZ     6
# Name: Group, Length: 86, dtype: int32
# 1.0168836978766256
# Ticker
# C       4
# VZ      1
# AMGN    1
# KO      0
# DHR     3
#        ..
# DD      4
# UNP     5
# COST    1
# MRK     1
# COF     4
# Name: Group, Length: 86, dtype: int32
# 1.0851914893141823
# Ticker
# AAPL    6
# QCOM    5
# GE      3
# COST    2
# PEP     0
#        ..
# T       6
# OXY     4
# MSFT    5
# PG      0
# MET     3
# Name: Group, Length: 86, dtype: int32
# 1.0517755711218517
# Ticker
# BLK     3
# AIG     1
# JPM     3
# OXY     6
# TMO     4
#        ..
# IBM     4
# MS      3
# DUK     5
# MSFT    4
# ORCL    4
# Name: Group, Length: 86, dtype: int32
# 0.9823450936303522
# Ticker
# TMO    2
# RTX    4
# AMT    2
# MO     0
# BMY    0
#       ..
# BK     6
# AIG    4
# WFC    4
# JPM    6
# C      6
# Name: Group, Length: 86, dtype: int32
# 0.984712706785662
# Ticker
# BA      2
# AMZN    0
# F       2
# DUK     3
# OXY     6
#        ..
# BAC     2
# BLK     2
# AXP     5
# ACN     1
# DHR     4
# Name: Group, Length: 86, dtype: int32
# 1.019463153683732
# Ticker
# TXN      4
# AXP      1
# MMM      4
# AAPL     4
# OXY      3
#         ..
# CL       5
# SO       5
# CMCSA    4
# ORCL     4
# CSCO     4
# Name: Group, Length: 86, dtype: int32
# 0.9353230653163539
# Ticker
# BK      0
# GS      0
# WFC     1
# AMGN    5
# BIIB    2
#        ..
# ALL     1
# MET     1
# COF     0
# WMT     5
# DD      0
# Name: Group, Length: 86, dtype: int32
# 1.1649277753708898
# Ticker
# INTC     1
# WMT      0
# EMR      2
# VZ       0
# IBM      1
#         ..
# OXY      3
# BRK-B    0
# AXP      2
# CVX      3
# BMY      0
# Name: Group, Length: 86, dtype: int32
# 0.9430814023888342
# Ticker
# QCOM    1
# SO      2
# XOM     5
# WFC     4
# WMT     6
#        ..
# LMT     5
# BKNG    0
# SPG     2
# NKE     0
# FDX     3
# Name: Group, Length: 86, dtype: int32
# 1.0936728072705102
# Ticker
# HON     0
# DUK     3
# CSCO    1
# COST    3
# DHR     1
#        ..
# ORCL    1
# BIIB    1
# ADBE    6
# AMZN    5
# MRK     3
# Name: Group, Length: 86, dtype: int32
# 0.9042108233276229
# Ticker
# LLY     1
# WFC     6
# COST    1
# GILD    5
# AIG     6
#        ..
# COP     4
# SBUX    2
# CVS     1
# CL      2
# SPG     2
# Name: Group, Length: 86, dtype: int32
# 0.9746498407900397
# Ticker
# EMR      5
# BRK-B    0
# AMT      4
# UPS      6
# UNH      6
#         ..
# PG       6
# KO       6
# NVDA     4
# PFE      1
# BKNG     4
# Name: Group, Length: 86, dtype: int32
# 0.9797532065138563
# Ticker
# TXN     3
# UPS     1
# LLY     4
# MDT     1
# EMR     6
#        ..
# TMO     3
# COST    4
# DD      0
# BMY     4
# CSCO    3
# Name: Group, Length: 86, dtype: int32
# 0.894519564118067
# Ticker
# ALL     2
# NKE     6
# CVX     3
# MMM     4
# MSFT    4
#        ..
# WFC     2
# ORCL    4
# NEE     1
# TMO     4
# COST    0
# Name: Group, Length: 86, dtype: int32
# 1.0713264342449365
# Ticker
# MMM     4
# ALL     5
# CVX     2
# PFE     4
# CVS     3
#        ..
# RTX     5
# GILD    4
# T       4
# AAPL    4
# EXC     3
# Name: Group, Length: 86, dtype: int32
# 0.9633935405958631
# Ticker
# FDX     3
# GD      0
# LLY     1
# MMM     4
# OXY     6
#        ..
# DUK     1
# LOW     2
# ACN     5
# COST    1
# INTC    4
# Name: Group, Length: 86, dtype: int32
# 1.110404051336082
# Ticker
# HD      5
# AMGN    6
# SPG     2
# LLY     6
# AIG     3
#        ..
# XOM     4
# COF     1
# COST    6
# GILD    0
# TGT     0
# Name: Group, Length: 86, dtype: int32
# 0.9306240494900659
# Ticker
# COST     1
# BIIB     2
# BRK-B    1
# MO       1
# MET      3
#         ..
# UNP      3
# BAC      6
# ALL      3
# PG       0
# CVS      1
# Name: Group, Length: 86, dtype: int32
# 1.071105847937206
# Ticker
# COP     2
# BKNG    1
# WFC     4
# XOM     2
# MMM     0
#        ..
# ABT     0
# ACN     1
# LOW     3
# PG      3
# JNJ     5
# Name: Group, Length: 86, dtype: int32
# 1.0204459320105543
# Ticker
# CL      5
# GE      0
# COF     3
# AXP     0
# LOW     5
#        ..
# PG      5
# F       3
# AIG     0
# GD      0
# BIIB    6
# Name: Group, Length: 86, dtype: int32
# 0.9003551410950019
# Ticker
# COP    3
# DD     1
# BMY    6
# PG     5
# PFE    2
#       ..
# CL     5
# BK     1
# EXC    6
# GS     1
# MCD    6
# Name: Group, Length: 86, dtype: int32
# 1.069067201109042
# Ticker
# ABT     6
# CSCO    6
# LLY     3
# MET     4
# DIS     0
#        ..
# SBUX    1
# ACN     5
# MDLZ    1
# BLK     0
# AAPL    6
# Name: Group, Length: 86, dtype: int32
# 0.9249436134575852
# Ticker
# USB     3
# BKNG    0
# BIIB    5
# WBA     5
# KO      6
#        ..
# UNP     3
# ABT     5
# SO      6
# HON     2
# JPM     2
# Name: Group, Length: 86, dtype: int32
# 1.013857617139006
# Ticker
# AAPL     3
# PEP      2
# NVDA     4
# AMT      4
# WMT      5
#         ..
# MMM      3
# BRK-B    5
# UNH      2
# MS       6
# NEE      2
# Name: Group, Length: 86, dtype: int32
# 0.9960700276486134
# Ticker
# COP     1
# TXN     0
# ORCL    0
# DUK     4
# RTX     3
#        ..
# ALL     3
# T       0
# COF     5
# ADBE    2
# IBM     0
# Name: Group, Length: 86, dtype: int32
# 0.8601595468305547
# Ticker
# OXY     3
# MDLZ    2
# TXN     1
# MSFT    1
# WBA     1
#        ..
# TGT     1
# UNP     4
# INTC    1
# KO      2
# PG      2
# Name: Group, Length: 86, dtype: int32
# 1.094301645811813
# Ticker
# F       1
# MDT     4
# JNJ     0
# GD      2
# MS      1
#        ..
# USB     2
# DHR     6
# VZ      0
# AMZN    4
# COP     3
# Name: Group, Length: 86, dtype: int32
# 1.0604061155210645
# Ticker
# HD      6
# WMT     2
# AMT     6
# CAT     1
# NKE     6
#        ..
# COST    2
# SO      0
# MS      5
# DHR     3
# BLK     5
# Name: Group, Length: 86, dtype: int32
# 0.9857526550859025
# Ticker
# PG      4
# DUK     6
# LMT     3
# MDLZ    4
# TGT     1
#        ..
# PFE     1
# MCD     6
# VZ      6
# C       5
# GILD    1
# Name: Group, Length: 86, dtype: int32
# 0.9825323036840302
# Ticker
# GILD    4
# AMGN    0
# UNH     6
# BMY     0
# PG      6
#        ..
# CVS     0
# KO      6
# GD      1
# MDLZ    6
# EMR     1
# Name: Group, Length: 86, dtype: int32
# 1.0030161607826542
# Ticker
# CSCO     1
# BIIB     1
# BLK      3
# CMCSA    1
# BA       3
#         ..
# MMM      1
# MET      6
# INTC     1
# DHR      1
# ORCL     1
# Name: Group, Length: 86, dtype: int32
# 0.9396705572248866
# Ticker
# BA     1
# IBM    5
# DD     1
# CAT    2
# AMT    6
#       ..
# TXN    5
# VZ     3
# EMR    2
# UNH    0
# BK     1
# Name: Group, Length: 86, dtype: int32
# 1.0524825569076717
# Ticker
# PG       4
# BIIB     5
# TGT      5
# UNH      4
# BRK-B    3
#         ..
# BLK      0
# CSCO     5
# UPS      4
# OXY      2
# NEE      4
# Name: Group, Length: 86, dtype: int32
# 1.0896768331499853
# Ticker
# SBUX    0
# JPM     1
# ORCL    4
# TMO     4
# BKNG    6
#        ..
# NEE     0
# GD      2
# BIIB    4
# CSCO    4
# ACN     6
# Name: Group, Length: 86, dtype: int32
# 0.9949459560779746
# Ticker
# MSFT    1
# BK      6
# JNJ     5
# PG      3
# NVDA    4
#        ..
# CAT     0
# GD      0
# LOW     3
# ORCL    1
# LMT     2
# Name: Group, Length: 86, dtype: int32
# 0.8680560502094836
# Ticker
# BRK-B    3
# BA       2
# LOW      0
# AMT      4
# AAPL     5
#         ..
# MCD      3
# GS       2
# TXN      5
# COP      6
# KO       0
# Name: Group, Length: 86, dtype: int32
# 1.0138886536441916
# Ticker
# GD      5
# MS      4
# PEP     0
# NKE     1
# INTC    6
#        ..
# DD      4
# EXC     3
# AMZN    0
# VZ      3
# COP     2
# Name: Group, Length: 86, dtype: int32
# 0.9265614100357565
# Ticker
# JNJ      5
# BA       0
# BKNG     4
# CMCSA    6
# MMM      6
#         ..
# DHR      6
# COF      0
# MSFT     6
# MDT      1
# BAC      0
# Name: Group, Length: 86, dtype: int32
# 0.9757921440027485
# Ticker
# USB     0
# COP     3
# BKNG    5
# XOM     3
# AIG     0
#        ..
# IBM     1
# CVS     6
# TMO     1
# JPM     2
# AAPL    1
# Name: Group, Length: 86, dtype: int32
# 0.9027886013722997
# Ticker
# CAT    2
# CVS    3
# RTX    2
# MRK    3
# ALL    2
#       ..
# PFE    0
# MET    2
# JPM    6
# ACN    5
# KO     1
# Name: Group, Length: 86, dtype: int32
# 0.9740766953616375
# Ticker
# GE     4
# VZ     0
# XOM    3
# MDT    6
# OXY    3
#       ..
# UNP    4
# WMT    0
# C      1
# BLK    1
# CAT    4
# Name: Group, Length: 86, dtype: int32
# 0.9182343208752222
# Ticker
# GD      0
# USB     0
# AMZN    3
# IBM     4
# MDT     3
#        ..
# ORCL    4
# BK      1
# VZ      2
# ALL     0
# AXP     0
# Name: Group, Length: 86, dtype: int32
# 1.1386747243700908
# Ticker
# HD      1
# DHR     5
# MCD     6
# UPS     2
# COF     0
#        ..
# ALL     4
# AXP     4
# WBA     5
# C       0
# AMZN    2
# Name: Group, Length: 86, dtype: int32
# 0.9808686494491772
# Ticker
# PFE     6
# AMGN    0
# CVS     0
# GILD    6
# MS      2
#        ..
# SPG     4
# MCD     0
# EMR     5
# DIS     2
# NKE     1
# Name: Group, Length: 86, dtype: int32
# 0.9027254669875456
# Ticker
# AMGN    2
# MET     6
# GILD    1
# GD      6
# DUK     2
#        ..
# BK      0
# CSCO    1
# INTC    1
# HON     0
# DD      0
# Name: Group, Length: 86, dtype: int32
# 0.9462369716512136
# Ticker
# SBUX    2
# F       5
# COF     5
# FDX     5
# COP     4
#        ..
# BKNG    6
# HD      6
# MET     0
# TGT     1
# GD      0
# Name: Group, Length: 86, dtype: int32
# 1.0811080580575747
# Ticker
# WFC     0
# WBA     3
# MCD     2
# AMGN    2
# AMZN    6
#        ..
# BK      5
# MDT     6
# QCOM    3
# MET     0
# CVS     2
# Name: Group, Length: 86, dtype: int32
# 0.9062762341306552
# Ticker
# AMZN    2
# MMM     1
# ABT     1
# BK      3
# BMY     5
#        ..
# ORCL    1
# LLY     5
# EXC     5
# FDX     3
# XOM     4
# Name: Group, Length: 86, dtype: int32
# 0.9294687468255128
# Ticker
# ORCL    5
# NEE     0
# BLK     4
# COP     6
# VZ      1
#        ..
# C       4
# EMR     2
# HON     4
# BMY     1
# JPM     4
# Name: Group, Length: 86, dtype: int32
# 1.0354657241246588
# Ticker
# MS     5
# MMM    0
# GE     3
# NEE    1
# NKE    4
#       ..
# C      5
# LLY    6
# RTX    3
# BA     5
# JPM    5
# Name: Group, Length: 86, dtype: int32
# 0.9853994101988313
# Ticker
# IBM     6
# SO      1
# JPM     2
# COP     3
# QCOM    6
#        ..
# NKE     0
# CAT     4
# OXY     3
# BLK     2
# BAC     2
# Name: Group, Length: 86, dtype: int32
# 0.961241410224584
# Ticker
# BA      6
# RTX     0
# AMGN    2
# JNJ     2
# GE      0
#        ..
# BIIB    4
# VZ      2
# HON     6
# IBM     4
# NKE     1
# Name: Group, Length: 86, dtype: int32
# 0.9669157752961414
# Ticker
# GE      2
# F       1
# IBM     0
# ORCL    0
# HON     1
#        ..
# CL      6
# HD      5
# WBA     0
# MRK     4
# BAC     1
# Name: Group, Length: 86, dtype: int32
# 0.9854753404604203
# Ticker
# MO      3
# HON     4
# AXP     2
# COST    3
# NEE     0
#        ..
# GS      4
# SO      0
# USB     2
# INTC    1
# BA      4
# Name: Group, Length: 86, dtype: int32
# 0.9591757854868133
# Ticker
# SBUX    5
# XOM     1
# MRK     3
# BLK     2
# WMT     3
#        ..
# CSCO    0
# BKNG    6
# GD      4
# F       2
# C       2
# Name: Group, Length: 86, dtype: int32
# 0.8639504556154719
# Ticker
# BA      3
# AMGN    4
# BAC     3
# MET     1
# HON     3
#        ..
# UNH     6
# TGT     0
# LLY     4
# UNP     1
# TXN     0
# Name: Group, Length: 86, dtype: int32
# 0.879238902374382
# Ticker
# BIIB    3
# GILD    3
# T       3
# GS      5
# GE      2
#        ..
# UNH     1
# BK      5
# GD      2
# MMM     3
# MET     2
# Name: Group, Length: 86, dtype: int32
# 0.792071211278114
# Ticker
# MET     3
# DIS     0
# TMO     1
# WFC     3
# XOM     6
#        ..
# PFE     1
# INTC    1
# COF     0
# SLB     6
# BIIB    1
# Name: Group, Length: 86, dtype: int32
# 0.9739245587066975
# Ticker
# HON     1
# BIIB    4
# PEP     6
# KO      6
# PFE     4
#        ..
# BLK     1
# JNJ     2
# ACN     4
# AIG     0
# PG      6
# Name: Group, Length: 86, dtype: int32
# 0.8033797682761971
# Ticker
# F       2
# IBM     4
# COST    5
# LMT     3
# VZ      5
#        ..
# EMR     1
# ACN     4
# BLK     2
# SBUX    0
# PFE     4
# Name: Group, Length: 86, dtype: int32
# 0.8988720083600804
# Ticker
# BKNG    1
# FDX     2
# SLB     3
# AMGN    5
# DD      2
#        ..
# QCOM    1
# IBM     1
# INTC    1
# UPS     0
# GD      4
# Name: Group, Length: 86, dtype: int32
# 0.9039798506198482
# Ticker
# MDT      1
# F        5
# PG       1
# TGT      4
# BRK-B    0
#         ..
# ORCL     4
# UNH      1
# LLY      0
# DD       5
# WBA      4
# Name: Group, Length: 86, dtype: int32
# 0.988621170379412
# Ticker
# DIS     0
# PFE     2
# SO      6
# SLB     3
# AMGN    1
#        ..
# INTC    2
# WFC     4
# CAT     4
# DD      0
# AIG     4
# Name: Group, Length: 86, dtype: int32
# 1.111502324753231
# Ticker
# BIIB     4
# GE       0
# COST     1
# JNJ      1
# CL       3
#         ..
# ACN      6
# TGT      6
# MSFT     6
# BKNG     6
# BRK-B    1
# Name: Group, Length: 86, dtype: int32
# 0.935467131923207
# Ticker
# BRK-B    1
# OXY      2
# RTX      6
# INTC     0
# KO       3
#         ..
# T        5
# JNJ      1
# AMT      0
# LMT      2
# UNP      6
# Name: Group, Length: 86, dtype: int32
# 0.9509053127624215
# Ticker
# GE     0
# HON    5
# TMO    3
# OXY    4
# GS     5
#       ..
# C      5
# MET    0
# BAC    5
# RTX    0
# CL     1
# Name: Group, Length: 86, dtype: int32
# 1.0230115291909492
# Ticker
# AAPL    6
# MSFT    6
# TMO     1
# INTC    6
# GS      5
#        ..
# OXY     2
# UPS     0
# DHR     1
# XOM     2
# SLB     2
# Name: Group, Length: 86, dtype: int32
# 1.0683661185663735
# Ticker
# UNH     4
# MSFT    6
# TGT     6
# MRK     1
# GE      5
#        ..
# JNJ     1
# COF     0
# BKNG    6
# DHR     2
# MDT     4
# Name: Group, Length: 86, dtype: int32
# 0.9656261015558505
# Ticker
# ABT     4
# BAC     5
# BKNG    2
# ADBE    2
# SBUX    1
#        ..
# MDT     1
# VZ      0
# JPM     5
# NVDA    2
# ALL     6
# Name: Group, Length: 86, dtype: int32
# 1.0963874031213878
# Ticker
# RTX     5
# AMGN    0
# MMM     4
# NEE     6
# GILD    4
#        ..
# MDLZ    6
# AMT     3
# ACN     3
# UNP     5
# PEP     6
# Name: Group, Length: 86, dtype: int32

# %%
# preselected_stock.to_csv('temp.csv')

# %%
#portfolio_beta["avg"]=portfolio_beta.loc[:,start_swan:end_swan]*weight

# %%
preselected_stock["PR"]=1-preselected_stock["avg"]
preselected_stock.head(selected_stock_number)
# Out:
# /tmp/ipykernel_671/2651548351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preselected_stock["PR"]=1-preselected_stock["avg"]
#            Swan4     Swan5     Swan6     Swan7     Swan8     Swan9   Swan10a  \
# Ticker
# ORCL    1.098732  0.741279  0.833162  0.841817  0.693684  0.643560  1.161396
# TMO     0.705951  0.957413  1.434218  0.888224  0.784559  0.786399  1.338748
# ABT     0.702188  0.474696  0.311079  1.073150  0.431921  0.941927  1.156495
# BIIB    1.431911  0.149965  0.925099  2.333501  1.054590  0.668161  1.232137
# CMCSA   1.470030  0.996273  1.036741  1.221346  0.301836  0.814080  0.616578
# PFE     0.820699  0.654960  0.746497  0.778217  0.441324  0.677535  1.115363
# T       1.384176  0.551527  0.419086  0.666460  0.908832  0.962824  0.551059
# DHR     0.720942  0.802835  1.280016  0.453165  0.631525  0.822711  1.322608
# QCOM    1.043829  0.641135  0.982422  1.165628  1.269623  0.964206  1.335199
# WBA     0.546247  0.760810  1.080813  1.124253  0.555843  0.515279  0.687883
# GILD    0.443015  0.154734  0.735171  0.992794  1.138347 -0.279531  1.282825
# NKE     1.123022  0.829711  0.536368  0.636695  0.862231  1.222210  1.872445
# MMM     0.185844  0.908566  1.478505  0.884500  0.834108  0.825408  1.242695
#
#         Group       avg        PR
# Ticker
# ORCL        4  0.527420  0.472580
# TMO         4  0.527420  0.472580
# ABT         4  0.527420  0.472580
# BIIB        4  0.685433  0.314567
# CMCSA       4  0.685433  0.314567
# PFE         4  0.685433  0.314567
# T           4  0.685433  0.314567
# DHR         4  1.146634 -0.146634
# QCOM        4  1.247040 -0.247040
# WBA         4  1.247040 -0.247040
# GILD        4  1.605539 -0.605539
# NKE         4  1.734570 -0.734570
# MMM         4  1.734570 -0.734570

# %% [markdown]
# # Step 2 - Download data and adjuste price based on Swan Beta

# %%
#next line is used to input preselected stock from excel, if you are going to preselect by your self, use this blocks and note next one.
#selected_stock_list =  pd.read_excel("19_stickers.xlsx",header = None).values[:,0]
#swan_beta=pd.read_excel("19_stickers.xlsx",header = None,index_col=0).iloc[:,0]

# %%
#Set the paramter to download tradeinfo from Yahoo Finance
selected_stock=preselected_stock
selected_stock_list=selected_stock.index.values
swan_beta=preselected_stock.loc[selected_stock_list,"avg"]

# %%
#download data from yahoo finance
yahooDataFrame= pdr.get_data_yahoo(list(selected_stock_list), start=start, end=end)["Adj Close"]
# Out:
# [*********************100%%**********************]  13 of 13 completed

# %%
yahooDataFrame
# Out:
# Ticker             ABT        BIIB      CMCSA         DHR       GILD  \
# Date
# 2019-01-02   63.287037  304.690002  30.364082   87.207214  51.315907
# 2019-01-03   60.300270  307.000000  30.602617   84.708145  52.780006
# 2019-01-04   62.021305  318.329987  31.636251   87.163834  55.206669
# 2019-01-07   62.950108  322.399994  31.300545   87.519592  55.457424
# 2019-01-08   62.194317  324.440002  31.556740   89.749680  55.077255
# ...                ...         ...        ...         ...        ...
# 2021-12-27  135.071182  234.190002  47.100624  287.357208  66.417831
# 2021-12-28  134.125900  235.990005  47.137951  283.872833  66.508965
# 2021-12-29  134.813370  258.309998  47.212612  286.814911  67.119637
# 2021-12-30  134.631973  240.000000  47.212612  288.474823  66.864433
# 2021-12-31  134.383713  239.919998  46.969971  288.949097  66.180840
#
# Ticker             MMM         NKE       ORCL        PFE        QCOM  \
# Date
# 2019-01-02  122.182968   70.124199  41.368904  32.894070   50.268066
# 2019-01-03  117.582275   68.883827  40.966373  31.973791   48.779282
# 2019-01-04  122.419716   70.682869  42.732002  32.703934   49.567451
# 2019-01-07  122.138191   71.696030  43.408985  32.878853   49.427326
# 2019-01-08  122.650078   72.652336  43.802368  33.030972   48.998215
# ...                ...         ...        ...        ...         ...
# 2021-12-27  127.586395  163.100189  86.083389  53.233276  176.740417
# 2021-12-28  128.265121  161.971207  85.227768  52.163216  175.308151
# 2021-12-29  128.821091  164.268097  84.804756  51.776562  176.617142
# 2021-12-30  128.265121  163.012589  84.612480  52.513912  173.325729
# 2021-12-31  128.257889  162.214523  83.843338  53.098396  173.458511
#
# Ticker              T         TMO        WBA
# Date
# 2019-01-02  14.461870  216.677170  52.906776
# 2019-01-03  14.481455  209.517792  52.354687
# 2019-01-04  14.853523  218.987915  54.096481
# 2019-01-07  15.122788  221.940567  54.407513
# 2019-01-08  15.313722  227.105164  55.496124
# ...               ...         ...        ...
# 2021-12-27  15.800819  658.553162  44.110512
# 2021-12-28  15.826327  651.760925  44.719166
# 2021-12-29  15.711552  659.070312  45.432163
# 2021-12-30  15.800819  661.775330  45.206100
# 2021-12-31  15.686041  663.555359  45.353916
#
# [757 rows x 13 columns]

# %%
#set parameters to calculate predict market drop
market_drop_info = pd.read_excel("MarketDD.xlsx",index_col=0)
swan_to_predict=9
total_day=yahooDataFrame.shape[0]
t1=int(round(market_drop_info.loc[:end_swan,"T1"].mean(),0))
t1=int((np.array(market_drop_info.loc[:end_swan,"T1"])*np.array(weight_swan)).sum())
#t2=total_day-t1
t2=int(round(market_drop_info.loc[:end_swan,"T2"].mean(),0))
dd=market_drop_info.loc[:end_swan,"Actual DD"].mean()
t0=int(total_day-t1-t2)

# %%
#calculate predict market drop
md = [] #Make market drop data list named md


j = 0 #Start from 0
inc = dd/(t1-1) #Calculate unit increasing market drop
for i in range(t1): #Append market drop data for t1
    md.append(round(j,4))
    j = j + inc

base = (t2+1)**(1/(dd*100)) #Calculate log base
l1 = [] #Make decreasing market drop list
for i in range(t2):
    l1.append(math.log((i+2),base)/100)

for i in range(t2): #Append market drop data for t2
    md.append(round((dd-l1[i]),4))

for i in range(t0):
    md.append(0)

market_drop = pd.DataFrame(md) #Change list into dataframe
market_drop = market_drop.rename(columns={0: 'Swan Drop spy'}) #Change column name
market_drop1 = pd.read_csv("trainingMarketdrop.csv")

# %%
market_drop.to_csv("market_drop.csv")

# %%
market_drop
# Out:
#      Swan Drop spy
# 0           0.0000
# 1           0.0040
# 2           0.0080
# 3           0.0119
# 4           0.0159
# ..             ...
# 752         0.0000
# 753         0.0000
# 754         0.0000
# 755         0.0000
# 756         0.0000
#
# [757 rows x 1 columns]

# %%
swan_drop_pct=np.array(swan_beta)*np.array(market_drop)
yahooDataFrame=pd.DataFrame((1-swan_drop_pct)*np.array(yahooDataFrame),index=yahooDataFrame.index,columns=yahooDataFrame.columns)

# %%
yahooDataFrame
# Out:
# Ticker             ABT        BIIB      CMCSA         DHR       GILD  \
# Date
# 2019-01-02   63.287037  304.690002  30.364082   87.207214  51.315907
# 2019-01-03   60.173056  306.352329  30.538056   84.475898  52.635298
# 2019-01-04   61.759615  316.986839  31.502767   86.685874  54.903945
# 2019-01-07   62.555014  320.376517  31.104093   86.805725  55.005077
# 2019-01-08   61.672757  321.719258  31.292106   88.771553  54.477002
# ...                ...         ...        ...         ...        ...
# 2021-12-27  135.071182  234.190002  47.100624  287.357208  66.417831
# 2021-12-28  134.125900  235.990005  47.137951  283.872833  66.508965
# 2021-12-29  134.813370  258.309998  47.212612  286.814911  67.119637
# 2021-12-30  134.631973  240.000000  47.212612  288.474823  66.864433
# 2021-12-31  134.383713  239.919998  46.969971  288.949097  66.180840
#
# Ticker             MMM         NKE       ORCL        PFE        QCOM  \
# Date
# 2019-01-02  122.182968   70.124199  41.368904  32.894070   50.268066
# 2019-01-03  117.259896   68.694966  40.778480  31.814301   48.535963
# 2019-01-04  121.748432   70.295282  42.340018  32.377669   49.072951
# 2019-01-07  121.141952   71.111230  42.816672  32.390938   48.693835
# 2019-01-08  121.313390   71.860543  43.003786  32.376035   48.026681
# ...                ...         ...        ...        ...         ...
# 2021-12-27  127.586395  163.100189  86.083389  53.233276  176.740417
# 2021-12-28  128.265121  161.971207  85.227768  52.163216  175.308151
# 2021-12-29  128.821091  164.268097  84.804756  51.776562  176.617142
# 2021-12-30  128.265121  163.012589  84.612480  52.513912  173.325729
# 2021-12-31  128.257889  162.214523  83.843338  53.098396  173.458511
#
# Ticker              T         TMO        WBA
# Date
# 2019-01-02  14.461870  216.677170  52.906776
# 2019-01-03  14.388453  208.064098  51.991435
# 2019-01-04  14.662740  215.949116  53.345808
# 2019-01-07  14.833854  217.359406  53.284466
# 2019-01-08  14.922792  220.841679  53.965560
# ...               ...         ...        ...
# 2021-12-27  15.800819  658.553162  44.110512
# 2021-12-28  15.826327  651.760925  44.719166
# 2021-12-29  15.711552  659.070312  45.432163
# 2021-12-30  15.800819  661.775330  45.206100
# 2021-12-31  15.686041  663.555359  45.353916
#
# [757 rows x 13 columns]

# %%
yahooDataFrame=yahooDataFrame.dropna(how="all",axis = 1)
selected_stock_list=yahooDataFrame.columns.values
selected_stock_number = yahooDataFrame.shape[1]
selected_stock_list
# Out:
# array(['ABT', 'BIIB', 'CMCSA', 'DHR', 'GILD', 'MMM', 'NKE', 'ORCL', 'PFE',
#        'QCOM', 'T', 'TMO', 'WBA'], dtype=object)

# %% [markdown]
# # Step3 - MVO

# %%
#Set the paramter for MVO process
Portfolio_Date=end

# %%
#data cleaning - filling missing data in yahooDataFrame
data_cleaning(yahooDataFrame)

# %%
bond_yield = quandl.get('FRED/DGS3MO')
bond_yield=np.log(bond_yield/100+1)
date=list(map(str,bond_yield.index.values))
date=list(map(modify_date,date))
week=pd.to_datetime(date).strftime("%W").values
week_1=np.roll(week,1)
week_difference=np.where(week!=week_1)
week_difference=np.delete(week_difference,0,None)
rf_week=bond_yield.iloc[week_difference-1]

# %%
# Calculated R for 1 year and 0.5 year
today_price = yahooDataFrame.iloc[-MA_days:,:]
one_year_ago_data = get_price_years_ago(yahooDataFrame,end,1)
one_year_ago_date = one_year_ago_data.index.values[-1]
half_year_ago_data = get_price_years_ago(yahooDataFrame,end,0.5)
half_year_ago_date = half_year_ago_data.index.values[-1]
one_year_ago_price=yahooDataFrame.loc[one_year_ago_date:,:]
one_year_ago_price=yahooDataFrame.iloc[:MA_days,:]
half_year_ago_price=yahooDataFrame.loc[half_year_ago_date:,:]
half_year_ago_price=yahooDataFrame.iloc[:MA_days,:]

R_mv_one_year=np.mean(pd.DataFrame(np.array(today_price)/np.array(one_year_ago_price)-1,index=today_price.index,columns=today_price.columns),axis=0)
R_mv_half_year=np.mean(pd.DataFrame(np.array(today_price)/np.array(half_year_ago_price)-1,index=today_price.index,columns=today_price.columns),axis=0)

# %%
R_mv_one_year.index
# Out:
# Index(['ABT', 'BIIB', 'CMCSA', 'DHR', 'GILD', 'MMM', 'NKE', 'ORCL', 'PFE',
#        'QCOM', 'T', 'TMO', 'WBA'],
#       dtype='object', name='Ticker')

# %%
# Calculate MA
MA_Data=yahooDataFrame.rolling(MA_days).mean().dropna(axis=0)
MA_Data=MA_Data.loc[one_year_ago_date:,:]
MA_now = MA_Data.iloc[-1,:]
MA_one_year_ago = MA_Data.iloc[0,:]
MA_half_year_ago = MA_Data.loc[half_year_ago_date,:]

# %%
# Calculate daily return
daily_return = yahooDataFrame.pct_change().dropna()
log_daily_return = np.log(1+daily_return)

# Get week end stock price data
stock_date = yahooDataFrame.index.values
week=pd.to_datetime(stock_date).strftime("%W").values
week_1=np.roll(week,1)
week_difference=np.where(week!=week_1)
week_difference=np.delete(week_difference,0,None)
# Calculate weekly return

weekly_return=yahooDataFrame.iloc[week_difference-1].pct_change().dropna()
log_weekly_return = np.log(1+weekly_return)

# Get month end stock price data
stock_date = yahooDataFrame.index.values
month=pd.to_datetime(stock_date).strftime("%m").values
month_1=np.roll(month,1)
month_difference=np.where(month!=month_1)
month_difference=np.delete(month_difference,0,None)
# Calculate monthly return
monthly_return=yahooDataFrame.iloc[month_difference-1].pct_change().dropna()
log_monthly_return = np.log(1+monthly_return)

# Get semi-month end stock price data
semi_month = []
for i in range(1,len(month_difference)):
    semi_month.append((month_difference[i]-month_difference[i-1])//2+month_difference[i-1])
    semi_month.append(month_difference[i]-1)
# Calculate semi-monthly return
semi_monthly_return=yahooDataFrame.iloc[semi_month].pct_change().dropna()
log_semi_monthly_return = np.log(1+semi_monthly_return)

# %%
# Calculated Max Dropdown for each stock
stock_return_one_year=daily_return.loc[one_year_ago_date:,:]
mdd=[]
for column in stock_return_one_year.columns:
    mdd .append(max_drawdown_absolute(stock_return_one_year.loc[:,column]))
mdd=pd.DataFrame(mdd,index = stock_return_one_year.columns,columns=["MAXDD","start_index","end_index"])
mar=R_mv_one_year/mdd.iloc[:,0]

# %%
#calculate weekly sd for each stock
one_year_weekly_return=log_weekly_return.iloc[log_weekly_return.index >= one_year_ago_date]
weekly_std= np.std(one_year_weekly_return)*np.sqrt(one_year_weekly_return.shape[0])

#Calculate garch_std sd for each stock
one_year_monthly_return=log_monthly_return.iloc[log_monthly_return.index >= one_year_ago_date]
res_all = one_year_monthly_return - np.mean(one_year_monthly_return)
judge = one_year_monthly_return.shape[0]
for stock in one_year_monthly_return.columns:
    res=res_all[stock]
    h= het_arch(res)
    if judge < 100 or h ==0:
        garch_std = weekly_std

    else:#build Garch Model
        std = []
        if judge <=200:
            p = 0
            q = 6
        else:
            p = 1
            q = 1

        std.append(fit_garch(one_year_monthly_return[stock],p,q))
        garch_std = pd.DataFrame(std,index = one_year_monthly_return.columns)

#Calculate monthly sd for each stock
one_year_monthly_return=log_monthly_return.iloc[log_monthly_return.index >= one_year_ago_date]
monthly_std = np.std(one_year_monthly_return)*np.sqrt(12);

#Calculate semi_monthly sd for each stock
one_year_semi_monthly_return=log_semi_monthly_return.iloc[log_semi_monthly_return.index >= one_year_ago_date]
semi_monthly_std = np.std(one_year_semi_monthly_return)*np.sqrt(24);

# %%
# Calculated MaxDrop
DD_range = 90
total_range = 90
DD_end = yahooDataFrame.iloc[yahooDataFrame.index <= one_year_ago_date]
DD_start = yahooDataFrame.iloc[yahooDataFrame.index <= end-datetime.timedelta(total_range)]
max_DD=[-1]*selected_stock_number


if (DD_start.shape[0] != 1 ) and (DD_end.shape[0] != 1):
    DD_start = DD_start.index[-1]
    DD_end = DD_end.index[-1]
    while DD_start > DD_end :
        DD_start = yahooDataFrame.iloc[yahooDataFrame.index <= end-datetime.timedelta(total_range)]
        DD_mid = yahooDataFrame.iloc[yahooDataFrame.index <= end-datetime.timedelta(DD_range+total_range)]
        if (DD_start.shape[0] != 1 ) and (DD_mid.shape[0] != 1):
            DD_start = DD_start.index[-1]
            DD_mid = DD_mid.index[-1]
            price = yahooDataFrame.loc[DD_start:DD_mid,:]
            for i in range(len(yahooDataFrame.columns)):
                max_DD[i]=max(max_DD[i],max_drawdown_absolute(stock_return_one_year.iloc[:,i])[0])
            total_range = total_range + 1
        else:
            break

# %%
optdata
# Out:
#            P_fwd  EPS_ttm  EPS_fwd  IsETF
# Symbol
# AAPL    306.8500    12.69    15.13      0
# ABBV     93.4600     9.53    10.37      0
# ABT      94.0700     3.25     3.82      0
# ACN     186.0900     7.60     8.09      0
# ADBE    338.5400     9.75    11.17      0
# ...          ...      ...      ...    ...
# WBA      47.9400     5.70     5.97      0
# WFC      36.9500     3.30     3.79      0
# WMT     129.2600     5.13     5.45      0
# XOM      48.3500     0.93     2.15      0
# AMT     305.7703     0.93     2.15      0
#
# [100 rows x 4 columns]

# %%
# Read OPT-data
optdata = pd.read_excel("optdata.xlsx",index_col=0,sheet_name = 1)
P_current = MA_now
P_fwd = optdata.P_fwd.loc[P_current.index]
R_fwd=P_fwd/P_current-1
R_60 = P_current/MA_one_year_ago - 1
R_60_half = P_current/MA_half_year_ago - 1
R_MA_1ago = R_mv_one_year
R_MA_halfago = R_mv_half_year
Rfwd_adjusted = pd.Series(index=R_MA_1ago.index)
for i in R_fwd.index:
    if R_fwd[i] < 0.5*R_60[i]:
        Rfwd_adjusted[i] = R_60_half[i]
    elif R_fwd[i] > 1.3*R_60[i]:
        if 1.3*R_60[i] > 0.7*R_fwd[i]:
            Rfwd_adjusted[i] = 1.3*R_60[i]
        else:
            Rfwd_adjusted[i] = 0.7*R_fwd[i]
    else:
        Rfwd_adjusted[i] = R_fwd[i]
Rfwd_adjusted[Rfwd_adjusted<0]=0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 4
#       2 optdata = pd.read_excel("optdata.xlsx",index_col=0,sheet_name = 1)
#       3 P_current = MA_now
# ----> 4 P_fwd = optdata.P_fwd.loc[P_current.index]
#       5 R_fwd=P_fwd/P_current-1
#       6 R_60 = P_current/MA_one_year_ago - 1
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1272, in _LocIndexer._getitem_iterable(self, key, axis)
#    1269 self._validate_key(key, axis)
#    1271 # A collection of keys
# -> 1272 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1273 return self.obj._reindex_with_indexers(
#    1274     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1275 )
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1462, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1459 ax = self.obj._get_axis(axis)
#    1460 axis_name = self.obj._get_axis_name(axis)
# -> 1462 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1464 return keyarr, indexer
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['TMO'] not in index"

# %%
price_now = today_price.iloc[-1,:]
optimizer = optdata.loc[P_current.index,:]
FFC = pd.DataFrame([R_MA_1ago.values,R_MA_halfago.values,MA_now.values,price_now.values,semi_monthly_std.values,weekly_std.values,MA_one_year_ago.values,MA_half_year_ago.values,max_DD,R_60.values,R_60_half.values,P_fwd.values,Rfwd_adjusted.values],columns = R_MA_1ago.index,index = ["R_MA_1ago","R_MA_halfago","MA_now","price",'std','std_f','MA_1ago','MA_halfago','Fall_MDD','R_60','R_60_half','R_fwd',"Rfwd_adjusted"]).T
preselected_stock = preselected_stock.loc[selected_stock_list,:]
preselected_stock["Rfwd_adjusted"]=Rfwd_adjusted.values
preselected_stock["std_f"]=weekly_std.values
preselected_stock["SR"]=preselected_stock["Rfwd_adjusted"]/preselected_stock["std_f"]
preselected_stock["PR_SR"]=preselected_stock["PR"]*preselected_stock["SR"]**0.5
preselected_stock.to_csv("preselected_Stocks_info.csv")
p=FFC.MA_now
EPS_fwd=optimizer.EPS_fwd
EPS_ttm=optimizer.EPS_ttm
fall=FFC.Fall_MDD
# FFC.to_csv("WEDataBank.csv")

PE=p/EPS_fwd
PEG= p/(EPS_fwd*(EPS_fwd/EPS_ttm-1))
PEG[PEG<0]=2000
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 2
#       1 price_now = today_price.iloc[-1,:]
# ----> 2 optimizer = optdata.loc[P_current.index,:]
#       3 FFC = pd.DataFrame([R_MA_1ago.values,R_MA_halfago.values,MA_now.values,price_now.values,semi_monthly_std.values,weekly_std.values,MA_one_year_ago.values,MA_half_year_ago.values,max_DD,R_60.values,R_60_half.values,P_fwd.values,Rfwd_adjusted.values],columns = R_MA_1ago.index,index = ["R_MA_1ago","R_MA_halfago","MA_now","price",'std','std_f','MA_1ago','MA_halfago','Fall_MDD','R_60','R_60_half','R_fwd',"Rfwd_adjusted"]).T
#       4 preselected_stock = preselected_stock.loc[selected_stock_list,:]
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1289, in _LocIndexer._getitem_tuple(self, tup)
#    1286 if self._multi_take_opportunity(tup):
#    1287     return self._multi_take(tup)
# -> 1289 return self._getitem_tuple_same_dim(tup)
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:955, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     952 if com.is_null_slice(key):
#     953     continue
# --> 955 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     956 # We should never have retval.ndim < self.ndim, as that should
#     957 #  be handled by the _getitem_lowerdim call above.
#     958 assert retval.ndim == self.ndim
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1272, in _LocIndexer._getitem_iterable(self, key, axis)
#    1269 self._validate_key(key, axis)
#    1271 # A collection of keys
# -> 1272 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1273 return self.obj._reindex_with_indexers(
#    1274     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1275 )
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexing.py:1462, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1459 ax = self.obj._get_axis(axis)
#    1460 axis_name = self.obj._get_axis_name(axis)
# -> 1462 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1464 return keyarr, indexer
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File /opt/atomsci-env/lib/python3.8/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['TMO'] not in index"

# %%
preselected_stock
# Out:
#            Swan4     Swan5     Swan6     Swan7     Swan8     Swan9   Swan10a  \
# Ticker
# AAPL    1.345472  0.858909  0.279703  1.582785  1.829198  0.972646  0.955996
# ADBE    1.599366  1.393154  1.278684  0.687330  1.210366  0.628947  1.680628
# AMZN   -0.445606  0.328167  0.123350  0.334033  1.561997  0.390752  1.440979
# BAC     0.594106  2.142401  2.667373  1.184257  1.192921  1.509426  1.144357
# BRK-B   0.220942  1.172896  0.533684  0.870710  0.663086  0.928445 -0.420873
# COST    0.829818  0.976294 -0.015790  0.618966  0.918643  0.368083  0.536185
# GOOGL        NaN  0.803565  1.167641  0.870361  0.938163  0.979057  0.880849
# GS      1.029728  1.064879  1.959793  1.207118  1.557229  1.356818  1.301592
# HD      1.546126  0.638987  0.756432  0.161429  1.098092  1.043489  1.605762
# JPM     1.649017  1.453522  1.887942  1.012903  0.969233  1.348489  1.440874
# LMT     0.009892  1.091646  0.569952  0.224948  1.448131  1.138289 -1.969023
# MA           NaN  0.644202  0.061049  0.805387  1.084036  1.300211  1.081897
# MSFT    0.870338  0.976788  0.607971  0.988753  0.897603  0.868731  1.244157
# NFLX         NaN -0.513562  3.473958  0.612869  1.902424  0.212860  3.055209
# NVDA    2.545656  0.635717  1.251062 -0.253400  2.787430  1.026747  2.039407
# TGT     1.178804  1.162603  0.421476  0.869800  1.393401  0.559241  0.684464
# UNH    -0.619292  0.706054  1.079657  0.775080  0.688288  1.138551  0.409690
# V            NaN  0.578961  0.335963  0.580043  0.919773  1.153300  0.948281
#
#              avg        PR  Rfwd_adjusted     std_f         SR     PR_SR
# Ticker
# AAPL    1.117816 -0.117816       0.578740  0.239959   2.411830 -0.182968
# ADBE    1.211211 -0.211211       0.153273  0.302558   0.506590 -0.150329
# AMZN    0.533381  0.466619       9.058544  0.241910  37.445897  2.855381
# BAC     1.490692 -0.490692       0.084898  0.246937   0.343806 -0.287717
# BRK-B   0.566984  0.433016       0.017195  0.142329   0.120813  0.150508
# COST    0.604600  0.395400       0.419931  0.191225   2.196008  0.585941
# GOOGL   0.939939  0.060061       6.547853  0.242882  26.958963  0.311848
# GS      1.353880 -0.353880       0.052422  0.262662   0.199578 -0.158093
# HD      0.978617  0.021383       0.308801  0.232805   1.326433  0.024627
# JPM     1.394569 -0.394569       0.018724  0.212973   0.087917 -0.116993
# LMT     0.359119  0.640881       0.242576  0.203677   1.190986  0.699408
# MA      0.829464  0.170536       0.000000  0.263515   0.000000  0.000000
# MSFT    0.922049  0.077951       0.298254  0.197170   1.512676  0.095873
# NFLX    1.457293 -0.457293       0.233542  0.287682   0.811808 -0.412023
# NVDA    1.433231 -0.433231       0.714120  0.400732   1.782039 -0.578334
# TGT     0.895684  0.104316       0.020756  0.239791   0.086557  0.030690
# UNH     0.596861  0.403139       0.179483  0.199298   0.900579  0.382574
# V       0.752720  0.247280       0.000000  0.237327   0.000000  0.000000

# %%
cov = pd.DataFrame(np.cov(np.exp(one_year_weekly_return)-1,rowvar=False,bias = False)*51,index= one_year_weekly_return.columns, columns= one_year_weekly_return.columns)
E_2 = Rfwd_adjusted/fall
E_3 = Rfwd_adjusted/PEG
E_4 = Rfwd_adjusted
std =  np.std(np.exp(one_year_weekly_return)-1)*np.sqrt(52)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# /Users/wenyiye/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %% [markdown]
# # Optimization

# %%
w0 = 1/selected_stock_number*np.ones(selected_stock_number)
uplim_ini = np.zeros(selected_stock_number)
uplim3 =pd.DataFrame( w1*(1-uplim_ini) + w2 * uplim_ini,index = std.index,columns=["weight"])
for i in uplim3.index:
    if i in ["SPY","IWD"]:
        uplim3.loc[i,:]=0
low_lim =  np.zeros(selected_stock_number)
multi=lambda x: x.T @cov@x

# %%
if method == "gptLowest8":
    cleaned_weights =  {'AMZN': 0.056, 'AAPL': 0.056, 'MSFT': 0.056, 'GOOGL': 0.056,
                  'NVDA': 0.056, 'NFLX': 0.056, 'MA': 0.056, 'V': 0.056,
                  'UNH': 0.056, 'JPM': 0.056, 'GS': 0.056, 'COST': 0.056,
                  'HD': 0.056, 'TGT': 0.056, 'ADBE': 0.056, 'BAC': 0.056,
                  'LMT': 0.056, 'BRK-B': 0.056}
    
else:
    ef = EfficientFrontier(E_2/100, cov,weight_bounds=(0, w1))
    #ef.add_constraint(lambda w: w@E_2== 12)
    raw_weights = ef.max_sharpe(0.01)
    cleaned_weights = ef.clean_weights()
    ef.portfolio_performance(verbose=True)
    
print(cleaned_weights)
# Out:
# Expected annual return: 25.2%
# Annual volatility: 11.5%
# Sharpe Ratio: 2.11
# OrderedDict([('AAPL', 0.0), ('ADBE', 0.0), ('AMZN', 0.17), ('BAC', 0.0), ('BRK-B', 0.14176), ('COST', 0.11802), ('GOOGL', 0.17), ('GS', 0.0), ('HD', 0.0), ('JPM', 0.09796), ('LMT', 0.11963), ('MA', 0.0), ('MSFT', 0.0), ('NFLX', 0.00478), ('NVDA', 0.0), ('TGT', 0.00784), ('UNH', 0.17), ('V', 0.0)])
# /Users/wenyiye/anaconda3/lib/python3.11/site-packages/pypfopt/efficient_frontier/efficient_frontier.py:441: UserWarning: The risk_free_rate provided to portfolio_performance is different to the one used by max_sharpe. Using the previous value.
#   warnings.warn(

# %%
weight1=np.array(pd.DataFrame(cleaned_weights.values(), index = list(cleaned_weights),columns = ["weight"]))[:,0]

# %%
sd1 = np.sqrt(weight1@cov@weight1.T)
R1 = weight1.T@E_2/100
sharpe_ratio1 = (R1-0.01)/sd1
print("new_sharpe:",sharpe_ratio1)
# Out:
# new_sharpe: 2.1096492834059033

# %% [markdown]
# weight2 =   pd.read_excel("old_weight.xlsx",index_col=0)
# weight2=np.array(weight2.loc[list(cleaned_weights),:])[:,0]

# %% [markdown]
# sd2 = np.sqrt(weight2@cov@weight2.T)
# R2 = weight2.T@E_2/100
# sharpe_ratio2 = (R2-0.01)/sd2
# print("old_sharpe:",sharpe_ratio2)

# %%
weight = pd.DataFrame(cleaned_weights.values(), index=list(cleaned_weights), columns=["weight"])
weight = weight[weight.weight >= 0.03]
weight.weight = weight.weight / sum(weight.weight)
weight.to_csv("weights.csv")

# %% [markdown]
# See pyportfolioopt.readthedocs.io/en/latest/MeanVariance.html for more reference

# %%
if stock_type == "S&P100":
    OEX=pdr.get_data_yahoo("^OEX", start=start_swan_date, end=end_swan_date)["Adj Close"]

elif stock_type == "S&P500":
    OEX=pdr.get_data_yahoo("SPY", start=start_swan_date, end=end_swan_date)["Adj Close"]

stock_price=pdr.get_data_yahoo(list(weight.index), start=start_swan_date, end=end_swan_date)["Adj Close"]
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  7 of 7 completed

# %%
stock_price.to_csv("tradeinfo.csv")
stock_price
# Out:
#                   AMZN       BRK-B        COST       GOOGL         JPM  \
# Date
# 2022-01-03  170.404495  300.790009  545.488037  144.991501  151.282242
# 2022-01-04  167.522003  308.529999  543.100952  144.399506  157.017334
# 2022-01-05  164.356995  309.920013  529.326660  137.774994  154.146729
# 2022-01-06  163.253998  313.220001  529.211243  137.747498  155.784393
# 2022-01-07  162.554001  319.779999  516.101196  137.016998  157.327927
# ...                ...         ...         ...         ...         ...
# 2022-12-23   85.250000  306.489990  448.304230   89.230003  126.698761
# 2022-12-27   83.040001  305.549988  444.282928   87.389999  127.142708
# 2022-12-28   81.820000  303.429993  438.943726   86.019997  127.837593
# 2022-12-29   84.180000  309.059998  442.374023   88.449997  128.571045
# 2022-12-30   84.000000  308.899994  442.344910   88.230003  129.420349
#
#                    LMT         UNH
# Date
# 2022-01-03  336.178009  488.573212
# 2022-01-04  343.416534  477.503723
# 2022-01-05  339.764099  476.326782
# 2022-01-06  339.631256  456.833618
# 2022-01-07  341.661560  446.085205
# ...                ...         ...
# 2022-12-23  470.532135  523.429626
# 2022-12-27  472.683807  524.099609
# 2022-12-28  470.464020  520.612122
# 2022-12-29  474.192902  522.020935
# 2022-12-30  473.647705  522.316406
#
# [251 rows x 7 columns]

# %%
start=stock_price.loc["2022-01-03"]
end = stock_price.loc["2022-10-12"]
stock_drop=abs(end/start-1)
market_drop = abs(OEX.loc["2022-10-12"]/OEX.loc["2022-01-03"]-1)

# %%
beta = stock_drop/market_drop
1-beta.T@weight
# Out:
# weight    0.248632
# dtype: float64

# %%
stock_drop
# Out:
# AMZN     0.337459
# BRK-B    0.122311
# COST     0.173026
# GOOGL    0.327133
# JPM      0.339021
# LMT      0.143832
# UNH      0.005030
# dtype: float64

# %%
print(stock_price.head(1))
weight
# Out:
#                   AMZN       BRK-B        COST       GOOGL         JPM  \
# Date
# 2022-01-03  170.404495  300.790009  545.488037  144.991501  151.282242
#
#                    LMT         UNH
# Date
# 2022-01-03  336.178009  488.573212
#          weight
# AMZN   0.172175
# BRK-B  0.143573
# COST   0.119530
# GOOGL  0.172175
# JPM    0.099213
# LMT    0.121160
# UNH    0.172175

# %%
a=stock_price@weight
b=1-a.loc["2022-10-12"]/a.loc["2022-01-03"]
1-b/market_drop
# Out:
# weight    0.594123
# dtype: float64

# %%
injected_result = pd.DataFrame(index = stock_price.index)
S1 = np.array(10000*weight.T)/np.array(stock_price.iloc[0,:]).T

# %%
portfolio_value = np.sum(np.array(weight.T) * stock_price,axis=1)
S1 = np.array(10000*weight.T)/np.array(stock_price.iloc[0,:]).T
injected_result["portfolio_value"]=stock_price@S1.T
S2 = 10000/float(OEX[0])
injected_result["oex"]=S2*OEX
injected_result.to_csv("Injected_result.csv")
# Out:
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2729638000.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   S2 = 10000/float(OEX[0])

# %%
temp=injected_result.loc[["2022-01-03","2022-10-12"]]
Portfolio_DD=abs(temp['portfolio_value'][1]/temp['portfolio_value'][0]-1)
DD=abs(temp['oex'][1]/temp['oex'][0]-1)
PR=1-(Portfolio_DD/DD)
print(PR)
temp
DD
# Out:
# 0.3829905043103061
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2994947419.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Portfolio_DD=abs(temp['portfolio_value'][1]/temp['portfolio_value'][0]-1)
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2994947419.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   DD=abs(temp['oex'][1]/temp['oex'][0]-1)
# 0.2722984138075022

# %%
allocation=pd.read_excel('allocation weight.xlsx',index_col='stock selected')
dfMVOstock=deepcopy(weight)
dfMVOstock['PR_SR']=''
dfMVOstock['SR']=''
for i in range(len(weight)):
    dfMVOstock.iloc[i,1]=preselected_stock.loc[weight.index[i],'PR_SR']
    dfMVOstock.iloc[i,2]=preselected_stock.loc[weight.index[i],'SR']
dfMVOstock_sort=dfMVOstock.sort_values(by='PR_SR',ascending=False)
postallocationweight=post_allocation(dfMVOstock_sort)
postallocationweight
# Out:
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2775426837.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (dfMVOweight.iloc[i,4]+residual/(numofstocks-i))>allocationweight[0]:
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2775426837.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dfMVOweight.iloc[i,5]=allocationweight[0]
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2775426837.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   for i in range(int(allocationweight[1])):
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2775426837.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dfMVOweight.iloc[i,6]=allocationweight[0]
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2775426837.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   for i in range(int(allocationweight[1]),int(allocationweight[1]+allocationweight[3])):
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/2775426837.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dfMVOweight.iloc[i,6]=allocationweight[2]
#          weight     PR_SR         SR     equal proportion adjusted proportion  \
# AMZN   0.055556  2.855381  37.445897  0.055556   0.878472                0.07
# LMT    0.055556  0.699408   1.190985  0.055556   0.215176                0.07
# COST   0.055556  0.585941   2.196005  0.055556   0.180268                0.07
# UNH    0.055556  0.382574   0.900578  0.055556   0.117701                0.07
# GOOGL  0.055556  0.311848  26.958963  0.055556   0.095941                0.07
# BRK-B  0.055556  0.150508   0.120813  0.055556   0.046305                0.07
# MSFT   0.055556  0.095873   1.512674  0.055556   0.029496                0.07
# TGT    0.055556   0.03069   0.086557  0.055556   0.009442                0.07
# HD     0.055556  0.024627   1.326435  0.055556   0.007577                0.07
# MA     0.055556       0.0        0.0  0.055556        0.0                0.07
# V      0.055556       0.0        0.0  0.055556        0.0                0.07
# JPM    0.055556 -0.116993   0.087917  0.055556  -0.035993                0.07
# ADBE   0.055556 -0.150329    0.50659  0.055556   -0.04625                0.07
# GS     0.055556 -0.158093   0.199578  0.055556  -0.048638            0.068989
# AAPL   0.055556 -0.182968   2.411831  0.055556  -0.056291            0.061336
# BAC    0.055556 -0.287717   0.343805  0.055556  -0.088517             0.02911
# NFLX   0.055556 -0.412023   0.811808  0.055556  -0.126761           -0.009134
# NVDA   0.055556 -0.578334   1.782039  0.055556  -0.177927             -0.0603
#
#        direct
# AMZN     0.07
# LMT      0.07
# COST     0.07
# UNH      0.07
# GOOGL    0.07
# BRK-B    0.07
# MSFT     0.07
# TGT      0.07
# HD       0.07
# MA       0.07
# V      0.0375
# JPM    0.0375
# ADBE   0.0375
# GS     0.0375
# AAPL   0.0375
# BAC    0.0375
# NFLX   0.0375
# NVDA   0.0375

# %%
#draw type E graph for postallocation
MVOweight=postallocationweight['weight']
equalweight=postallocationweight['equal']
proportionweight=postallocationweight['adjusted proportion']
directweight=postallocationweight['direct']
output(MVOweight).to_csv('no_post_allocation_result.csv')
output(equalweight).to_csv('equal_weight_result.csv')
output(proportionweight).to_csv('proportional_weight_result.csv')
output(directweight).to_csv('direct_weight_result.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  8 of 8 completed
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/1728796536.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   S2 = 10000/float(OEX[0])
# [*********************100%%**********************]  8 of 8 completed
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/1728796536.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   S2 = 10000/float(OEX[0])
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  8 of 8 completed
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/1728796536.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   S2 = 10000/float(OEX[0])
# [*********************100%%**********************]  8 of 8 completed
# /var/folders/6g/__5vs7k9339d_y5ztlb880wm0000gn/T/ipykernel_46265/1728796536.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   S2 = 10000/float(OEX[0])
